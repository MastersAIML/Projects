# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
print(nltk_data[:40])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')], [('Lorillard', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('the', 'DET'), ('unit', 'NOUN'), ('of', 'ADP'), ('New', 'ADJ'), ('York-based', 'ADJ'), ('Loews', 'NOUN'), ('Corp.', 'NOUN'), ('that', 'DET'), ('*T*-2', 'X'), ('makes', 'VERB'), ('Kent', 'NOUN'), ('cigarettes', 'NOUN'), (',', '.'), ('stopped', 'VERB'), ('using', 'VERB'), ('crocidolite', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('Micronite', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('in', 'ADP'), ('1956', 'NUM'), ('.', '.')], [('Although', 'ADP'), ('preliminary', 'ADJ'), ('findings', 'NOUN'), ('were', 'VERB'), ('reported', 'VERB'), ('*-2', 'X'), ('more', 'ADV'), ('than', 'ADP'), ('a', 'DET'), ('year', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('the', 'DET'), ('latest', 'ADJ'), ('results', 'NOUN'), ('appear', 'VERB'), ('in', 'ADP'), ('today', 'NOUN'), ("'s", 'PRT'), ('New', 'NOUN'), ('England', 'NOUN'), ('Journal', 'NOUN'), ('of', 'ADP'), ('Medicine', 'NOUN'), (',', '.'), ('a', 'DET'), ('forum', 'NOUN'), ('likely', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('bring', 'VERB'), ('new', 'ADJ'), ('attention', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('problem', 'NOUN'), ('.', '.')], [('A', 'DET'), ('Lorillard', 'NOUN'), ('spokewoman', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('This', 'DET'), ('is', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('story', 'NOUN'), ('.', '.')], [('We', 'PRON'), ("'re", 'VERB'), ('talking', 'VERB'), ('about', 'ADP'), ('years', 'NOUN'), ('ago', 'ADP'), ('before', 'ADP'), ('anyone', 'NOUN'), ('heard', 'VERB'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('having', 'VERB'), ('any', 'DET'), ('questionable', 'ADJ'), ('properties', 'NOUN'), ('.', ...

# %%
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import time

random.seed(1234)
train_set, val_set = train_test_split(nltk_data,test_size=0.05)

# Getting list of tagged words
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)

# number of tags
T = set([pair[1] for pair in train_tagged_words])
print (T)

# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')

# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))
tags_df
# Out:
# {'.', 'NUM', 'NOUN', 'ADJ', 'VERB', 'X', 'ADP', 'PRT', 'CONJ', 'ADV', 'DET', 'PRON'}
#              .       NUM      NOUN       ADJ      VERB         X       ADP  \
# .     0.093756  0.080220  0.220809  0.045208  0.088251  0.026890  0.092944
# NUM   0.116929  0.182684  0.357334  0.034514  0.018744  0.206486  0.035406
# NOUN  0.238952  0.009618  0.263725  0.012277  0.147473  0.028963  0.177639
# ADJ   0.065367  0.020970  0.697248  0.068152  0.012123  0.021298  0.076343
# VERB  0.034202  0.022956  0.109508  0.065147  0.169769  0.218163  0.090817
# X     0.160326  0.002558  0.063459  0.017104  0.204124  0.075448  0.144182
# ADP   0.039157  0.063205  0.320600  0.107470  0.008300  0.034050  0.017131
# PRT   0.043109  0.056826  0.247877  0.083932  0.399739  0.013717  0.021228
# CONJ  0.034998  0.042464  0.350910  0.118059  0.155390  0.007933  0.049930
# ADV   0.136603  0.030612  0.031929  0.127716  0.342989  0.023041  0.118828
# DET   0.018046  0.022257  0.640159  0.203441  0.039581  0.044634  0.009384
# PRON  0.041602  0.006549  0.213790  0.072419  0.484977  0.090139  0.023883
#
#            PRT      CONJ       ADV       DET      PRON
# .     0.002346  0.058202  0.052247  0.173705  0.065331
# NUM   0.026778  0.013389  0.002975  0.003273  0.001488
# NOUN  0.043681  0.042588  0.017378  0.013152  0.004554
# ADJ   0.010976  0.016874  0.004915  0.005079  0.000655
# VERB  0.031798  0.005429  0.082131  0.134559  0.035520
# X     0.185902  0.009431  0.025895  0.054987  0.056586
# ADP   0.001383  0.000426  0.014152  0.324963  0.069164
# PRT   0.001633  0.002286  0.010124  0.100914  0.018615
# CONJ  0.005133  0.000467  0.055996  0.120859  0.057863
# ADV   0.014812  0.007242  0.081633  0.069783  0.014812
# DET   0.000241  0.000481  0.012753  0.005654  0.003369
# PRON  0.011941  0.005393  0.031972  0.009245  0.008089

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            count_w_given_tag, count_tag = word_given_tag(words[key], tag)
            emission_p = count_w_given_tag/count_tag
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# list of tagged words
val_run_base = [tup for sent in val_set for tup in sent]

# list of untagged words
val_tagged_words = [tup[0] for sent in val_set for tup in sent]
val_tagged_words
# Out:
# ['They',
#  'must',
#  'figure',
#  'that',
#  'justice',
#  'has',
#  '*-2',
#  'to',
#  'get',
#  'done',
#  '*-3',
#  'by',
#  'somebody',
#  ',',
#  'but',
#  'know',
#  '0',
#  'it',
#  'wo',
#  "n't",
#  'be',
#  'done',
#  '*-1',
#  'by',
#  'Congress',
#  '.',
#  'The',
#  'vicar',
#  ',',
#  'W.D.',
#  'Jones',
#  ',',
#  'refuses',
#  '*-1',
#  'to',
#  'talk',
#  'about',
#  'it',
#  ',',
#  '*-1',
#  'saying',
#  '0',
#  'it',
#  'would',
#  '``',
#  'reopen',
#  'the',
#  'wound',
#  '.',
#  "''",
#  'Other',
#  'rumored',
#  'takeover',
#  'and',
#  'restructuring',
#  'candidates',
#  '0',
#  '*T*-2',
#  'to',
#  'attract',
#  'buyers',
#  'included',
#  'Woolworth',
#  ',',
#  'which',
#  '*T*-1',
#  'went',
#  'up',
#  '1',
#  '3\\/4',
#  'to',
#  '59',
#  '1\\/2',
#  ';',
#  'Avon',
#  'Products',
#  ',',
#  'up',
#  '1',
#  '3\\/4',
#  'to',
#  '29',
#  '1\\/4',
#  ';',
#  'Paramount',
#  'Communications',
#  ',',
#  'up',
#  '2',
#  'to',
#  '57',
#  '7\\/8',
#  ',',
#  'and',
#  'Ferro',
#  ',',
#  'up',
#  '2',
#  '5\\/8',
#  'to',
#  '28',
#  '3\\/4',
#  '.',
#  'The',
#  'campaign',
#  'has',
#  'blamed',
#  'these',
#  'reporting',
#  'problems',
#  'on',
#  'computer',
#  'errors',
#  '.',
#  'When',
#  'two',
#  'parties',
#  'engage',
#  'in',
#  'an',
#  'interest-rate',
#  'swap',
#  '*T*-1',
#  ',',
#  'they',
#  'are',
#  'betting',
#  'against',
#  'each',
#  'other',
#  'on',
#  'future',
#  'rates',
#  '.',
#  'The',
#  'panel',
#  'ruled',
#  'that',
#  'the',
#  'restrictions',
#  'do',
#  "n't",
#  'violate',
#  'the',
#  'freedom',
#  'of',
#  'speech',
#  'of',
#  'health',
#  'care',
#  'providers',
#  'and',
#  'that',
#  'the',
#  'limits',
#  'on',
#  'counseling',
#  'services',
#  'do',
#  "n't",
#  'violate',
#  'the',
#  'rights',
#  'of',
#  'pregnant',
#  'women',
#  '.',
#  'He',
#  'declined',
#  '*-1',
#  'to',
#  'elaborate',
#  ',',
#  'other',
#  'than',
#  '*-1',
#  'to',
#  'say',
#  ',',
#  '``',
#  'It',
#  'just',
#  'seemed',
#  'the',
#  'right',
#  'thing',
#  '0',
#  '*',
#  'to',
#  'do',
#  '*T*-2',
#  'at',
#  'this',
#  'minute',
#  '.',
#  'In',
#  'Syracuse',
#  ',',
#  'N.Y.',
#  ',',
#  'DyDee',
#  'Service',
#  "'s",
#  'new',
#  'marketing',
#  'push',
#  'stresses',
#  'environmental',
#  'awareness',
#  '.',
#  'They',
#  'say',
#  'that',
#  'many',
#  'vehicles',
#  'classed',
#  '*',
#  'as',
#  'commercial',
#  'light',
#  'trucks',
#  'actually',
#  'carry',
#  'more',
#  'people',
#  'than',
#  'cargo',
#  'and',
#  'therefore',
#  'should',
#  'have',
#  'the',
#  'same',
#  'safety',
#  'features',
#  'as',
#  'cars',
#  '.',
#  'Indeed',
#  ',',
#  'Mrs.',
#  'Yeargin',
#  'was',
#  'interested',
#  'in',
#  'a',
#  'possible',
#  'job',
#  'with',
#  'the',
#  'state',
#  'teacher',
#  'cadet',
#  'program',
#  '.',
#  'Since',
#  'chalk',
#  'first',
#  'touched',
#  'slate',
#  ',',
#  'schoolchildren',
#  'have',
#  'wanted',
#  '*-1',
#  'to',
#  'know',
#  ':',
#  'What',
#  "'s",
#  '*T*-2',
#  'on',
#  'the',
#  'test',
#  '?',
#  '``',
#  'You',
#  "'re",
#  'dead',
#  'in',
#  'the',
#  'water',
#  'if',
#  'you',
#  'are',
#  "n't",
#  'segmenting',
#  'the',
#  'market',
#  ',',
#  "''",
#  'says',
#  '*T*-1',
#  'Anne',
#  'Moore',
#  ',',
#  'president',
#  'of',
#  'Synergistics',
#  'Research',
#  'Corp.',
#  ',',
#  'a',
#  'bank',
#  'consulting',
#  'firm',
#  'in',
#  'Atlanta',
#  '.',
#  'Many',
#  'of',
#  'them',
#  'recently',
#  'have',
#  'been',
#  'spending',
#  'a',
#  'lot',
#  'of',
#  'money',
#  'on',
#  'public',
#  'relations',
#  'and',
#  'advertising',
#  '*-1',
#  'to',
#  'improve',
#  'their',
#  'images',
#  ',',
#  'but',
#  'they',
#  'should',
#  'realize',
#  'that',
#  'the',
#  'most',
#  'important',
#  'thing',
#  'is',
#  'real',
#  'change',
#  ',',
#  'not',
#  '*',
#  'changing',
#  'people',
#  "'s",
#  'perceptions',
#  '.',
#  'The',
#  'combined',
#  'processes',
#  'may',
#  'significantly',
#  'raise',
#  'the',
#  'current-carrying',
#  'capacity',
#  'of',
#  'multi-crystal',
#  'samples',
#  '.',
#  'Mr.',
#  'McGovern',
#  ',',
#  '63',
#  ',',
#  'had',
#  'been',
#  'under',
#  'intense',
#  'pressure',
#  '*ICH*-1',
#  'from',
#  'the',
#  'board',
#  '*',
#  'to',
#  'boost',
#  'Campbell',
#  "'s",
#  'mediocre',
#  'performance',
#  'to',
#  'the',
#  'level',
#  'of',
#  'other',
#  'food',
#  'companies',
#  '.',
#  'The',
#  'nation',
#  "'s",
#  'largest',
#  'steelmaker',
#  'earned',
#  '$',
#  '175',
#  'million',
#  '*U*',
#  ',',
#  'or',
#  '62',
#  'cents',
#  'a',
#  'share',
#  ',',
#  'compared',
#  'with',
#  'the',
#  'year-earlier',
#  '$',
#  '228',
#  'million',
#  '*U*',
#  ',',
#  'or',
#  '80',
#  'cents',
#  'a',
#  'share',
#  '.',
#  'Mr.',
#  'Rapanelli',
#  'met',
#  'in',
#  'August',
#  'with',
#  'U.S.',
#  'Assistant',
#  'Treasury',
#  'Secretary',
#  'David',
#  'Mulford',
#  '.',
#  '4',
#  '.',
#  '*',
#  'Buy',
#  'a',
#  'diamond',
#  'necklace',
#  '.',
#  'The',
#  'show',
#  'did',
#  "n't",
#  'give',
#  'the',
#  'particulars',
#  'of',
#  'Mrs.',
#  'Yeargin',
#  "'s",
#  'offense',
#  ',',
#  '*-1',
#  'saying',
#  'only',
#  'that',
#  'she',
#  'helped',
#  'students',
#  'do',
#  'better',
#  'on',
#  'the',
#  'test',
#  '.',
#  'Takeover',
#  'experts',
#  'said',
#  '0',
#  'they',
#  'doubted',
#  '0',
#  'the',
#  'financier',
#  'would',
#  'make',
#  'a',
#  'bid',
#  'by',
#  'himself',
#  '.',
#  'While',
#  '*-1',
#  'neither',
#  'admitting',
#  'nor',
#  'denying',
#  'wrongdoing',
#  ',',
#  'Triton',
#  'and',
#  'Mr.',
#  'Chase',
#  'consented',
#  'to',
#  'findings',
#  'of',
#  'violations',
#  'in',
#  'connection',
#  'with',
#  'limited-partnership',
#  'sales',
#  '.',
#  'In',
#  'most',
#  'of',
#  'the',
#  'British',
#  'transactions',
#  ',',
#  'the',
#  'municipalities',
#  'agreed',
#  '*-1',
#  'to',
#  'make',
#  'floating-rate',
#  'payments',
#  'to',
#  'banks',
#  ',',
#  'which',
#  '*T*-62',
#  'would',
#  'make',
#  'fixed-rate',
#  'payments',
#  '.',
#  'The',
#  'new',
#  'securities',
#  ',',
#  'part',
#  'of',
#  'the',
#  'federal',
#  'government',
#  "'s",
#  'regular',
#  'quarterly',
#  'refunding',
#  ',',
#  'will',
#  'consist',
#  'of',
#  ':',
#  '``',
#  'These',
#  'kids',
#  'broke',
#  'my',
#  'heart',
#  ',',
#  "''",
#  'she',
#  'says',
#  '*T*-1',
#  '.',
#  'The',
#  'last',
#  'thing',
#  '0',
#  'they',
#  'needed',
#  '*T*-1',
#  'was',
#  'another',
#  'drag-down',
#  'blow',
#  '.',
#  "''",
#  '``',
#  'It',
#  'is',
#  'going',
#  '*-1',
#  'to',
#  'be',
#  'real',
#  'tight',
#  '.',
#  "''",
#  'It',
#  'does',
#  'a',
#  'first-rate',
#  'job',
#  '.',
#  'Odyssey',
#  'Partners',
#  'Limited',
#  'Partnership',
#  ',',
#  'an',
#  'investment',
#  'firm',
#  ',',
#  'completed',
#  'the',
#  'purchase',
#  'of',
#  'May',
#  'Department',
#  'Stores',
#  'Co.',
#  "'s",
#  'Caldor',
#  'discount',
#  'chain',
#  'for',
#  '$',
#  '500',
#  'million',
#  '*U*',
#  'plus',
#  'the',
#  'assumption',
#  'of',
#  '$',
#  '52',
#  'million',
#  '*U*',
#  'in',
#  'debt',
#  '.',
#  'In',
#  '*-2',
#  'ending',
#  'Hungary',
#  "'s",
#  'part',
#  'of',
#  'the',
#  'project',
#  ',',
#  'Parliament',
#  'authorized',
#  'Prime',
#  'Minister',
#  'Miklos',
#  'Nemeth',
#  'to',
#  'modify',
#  'a',
#  '1977',
#  'agreement',
#  'with',
#  'Czechoslovakia',
#  ',',
#  'which',
#  '*T*-64',
#  'still',
#  'wants',
#  'the',
#  'dam',
#  'to',
#  'be',
#  'built',
#  '*-1',
#  '.',
#  'Country',
#  'funds',
#  'offer',
#  'an',
#  'easy',
#  'way',
#  '0',
#  '*',
#  'to',
#  'get',
#  'a',
#  'taste',
#  'of',
#  'foreign',
#  'stocks',
#  'without',
#  'the',
#  'hard',
#  'research',
#  'of',
#  '*',
#  'seeking',
#  'out',
#  'individual',
#  'companies',
#  '*T*-1',
#  '.',
#  'MEDICINE',
#  'TRANSPLANT',
#  ':',
#  'Growth',
#  'of',
#  'Japanese',
#  'trade',
#  'and',
#  'travel',
#  'prompts',
#  'Beth',
#  'Israel',
#  'Medical',
#  'Center',
#  ',',
#  'New',
#  'York',
#  ',',
#  'to',
#  'set',
#  'up',
#  'a',
#  'bilingual',
#  'medical',
#  'practice',
#  '.',
#  '``',
#  'So',
#  'Long',
#  ',',
#  'L.A.',
#  "''",
#  'was',
#  'chosen',
#  '*-1',
#  'as',
#  'the',
#  'paper',
#  "'s",
#  'final',
#  'headline',
#  '.',
#  'Occidental',
#  'Petroleum',
#  'Corp.',
#  ',',
#  'shelf',
#  'offering',
#  'of',
#  '$',
#  '1.5',
#  'billion',
#  '*U*',
#  'in',
#  'senior',
#  'debt',
#  'securities',
#  '.',
#  'Says',
#  '0',
#  '*ICH*-3',
#  'the',
#  'organization',
#  "'s",
#  'founder',
#  ',',
#  'John',
#  'Cannell',
#  ',',
#  '*',
#  'prosecuting',
#  'Mrs.',
#  'Yeargin',
#  'is',
#  '``',
#  'a',
#  'way',
#  'for',
#  '0',
#  'administrators',
#  'to',
#  'protect',
#  'themselves',
#  '*T*-4',
#  'and',
#  'look',
#  'like',
#  'they',
#  'take',
#  'cheating',
#  'seriously',
#  '*T*-4',
#  ',',
#  'when',
#  'in',
#  'fact',
#  'they',
#  'do',
#  "n't",
#  'take',
#  'it',
#  'seriously',
#  'at',
#  'all',
#  '*T*-1',
#  '.',
#  "''",
#  'There',
#  'is',
#  '$',
#  '30.9',
#  'million',
#  '*U*',
#  'of',
#  'fourth',
#  'series',
#  'bonds',
#  ',',
#  'the',
#  'interest',
#  'on',
#  'which',
#  '*T*-1',
#  'is',
#  'not',
#  'subject',
#  'to',
#  'the',
#  'federal',
#  'alternative',
#  'minimum',
#  'tax',
#  '.',
#  'One',
#  'survey',
#  'says',
#  'that',
#  'of',
#  'the',
#  '100,000',
#  'trained',
#  'bellringers',
#  'in',
#  'England',
#  'today',
#  ',',
#  'only',
#  '40,000',
#  'of',
#  'them',
#  'still',
#  'ring',
#  '.',
#  'The',
#  'council',
#  ',',
#  'which',
#  '*T*-61',
#  'is',
#  'alleged',
#  '*-1',
#  'to',
#  'have',
#  'engaged',
#  'in',
#  'over',
#  '600',
#  'deals',
#  'valued',
#  '*',
#  'at',
#  'over',
#  '#',
#  '6',
#  'billion',
#  '*U*',
#  '-LRB-',
#  '$',
#  '9.5',
#  'billion',
#  '*U*',
#  '-RRB-',
#  ',',
#  'lost',
#  'millions',
#  'of',
#  'pounds',
#  'from',
#  'soured',
#  'swap',
#  'deals',
#  '.',
#  'Second',
#  ',',
#  'it',
#  'can',
#  'be',
#  'used',
#  '*-1',
#  '*',
#  'to',
#  'unwind',
#  'positions',
#  'before',
#  'U.S.',
#  'trading',
#  'begins',
#  ',',
#  'but',
#  'at',
#  'prices',
#  'pegged',
#  '*',
#  'to',
#  'the',
#  'previous',
#  'session',
#  "'s",
#  'Big',
#  'Board',
#  'close',
#  '.',
#  'It',
#  '*EXP*-3',
#  "'s",
#  'probably',
#  'true',
#  'that',
#  'many',
#  'salarymen',
#  'put',
#  'in',
#  'unproductive',
#  'overtime',
#  'just',
#  'for',
#  'the',
#  'sake',
#  'of',
#  'solidarity',
#  ',',
#  'that',
#  'the',
#  'system',
#  'is',
#  'so',
#  'hierarchical',
#  'that',
#  'only',
#  'the',
#  'assistant',
#  'manager',
#  'can',
#  'talk',
#  'to',
#  'the',
#  'manager',
#  'and',
#  'the',
#  'manager',
#  'to',
#  'the',
#  'general',
#  'manager',
#  ',',
#  'and',
#  'that',
#  'Sony',
#  'was',
#  'chary',
#  'of',
#  '*-4',
#  'letting',
#  'a',
#  'young',
#  ',',
#  'short-term',
#  'American',
#  'employee',
#  'take',
#  'on',
#  'any',
#  'responsibility',
#  '.',
#  'Excision',
#  'of',
#  'appropriations',
#  'riders',
#  'that',
#  '*T*-1',
#  'trespass',
#  'on',
#  'the',
#  'president',
#  "'s",
#  'duties',
#  'and',
#  'prerogative',
#  'under',
#  'Article',
#  'II',
#  'would',
#  'be',
#  'different',
#  'from',
#  ...]

# %% [markdown]
# ### Solve the problem of unknown words

# %%
import re
import collections

# Addtional check for the right tagger
def checkNumberTagger(word):
    # check if it is a number
    pattern = "[0-9]+[\:,\,]*[0-9]+"
    if re.match(pattern, word):
        print ("Correcting :: ", word, " to NUM")
        return 'NUM'
    else:
        return 'None'
    
# Instead of usign a random tagger, use biagram to tag based on frequency of the previous tag
def checkBiagramTagger(prev_tag, word, train_bag):
    word_tag_pairs = nltk.bigrams(train_bag)
    tag_seq_noun = list(nltk.FreqDist(a[1] for (a, b) in word_tag_pairs if b[1] == 'NOUN'))
    if prev_tag in tag_seq_noun:
        print ("Correcting :: ", word, " to NOUN when prev tag is ", prev_tag)
        return 'NOUN'
    else:
        return 'None'

# Instead of usign a random tagger, returning the most common tagger for unknown tags
def checkLexicanTagger(word):
    pos_list = nltk.pos_tag([pair[0] for pair in train_tagged_words],'universal')
    pos_counts = collections.Counter((subl[1] for subl in pos_list))
    most_common_tag = pos_counts.most_common(1)[0][0]
    print ("Correcting :: ", word, " with most common tag ", most_common_tag)
    return most_common_tag

# Viterbi Heuristic
def ViterbiNew(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            count_w_given_tag, count_tag = word_given_tag(words[key], tag)
            emission_p = count_w_given_tag/count_tag
            state_probability = emission_p * transition_p    
            p.append(state_probability)    
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        # Checking Rule based Tagger in case the transition probabilit is zero. The vanila method was defaulting to first element
        if pmax == 0:
            state_max = checkNumberTagger(word)
            if (state_max == 'None' and len(state) > 0):
                state_max = checkBiagramTagger(state[key-1], word, train_bag)
            if (state_max == 'None'):
                state_max = checkLexicanTagger(word)
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
# tagging the validation sentences
start = time.time()
tagged_seq = Viterbi(val_tagged_words)
end = time.time()
difference = end-start
print ("Time Taken with Vanila Viterbi on Validation Data ::", difference)
# accuracy
check = [i for i, j in zip(tagged_seq, val_run_base) if i == j] 
accuracy_vanila = len(check)/len(tagged_seq)
print ("Accuracy ::", accuracy_vanila)
incorrect_tagged_cases_vanila = [[val_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, val_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases_vanila
# Out:
# Time Taken with Vanila Viterbi on Validation Data :: 323.891578912735
# Accuracy :: 0.9080505922505521
# [[(',', '.'), (('W.D.', '.'), ('W.D.', 'NOUN'))],
#  [(',', '.'), (('refuses', '.'), ('refuses', 'VERB'))],
#  [('the', 'DET'), (('wound', 'VERB'), ('wound', 'NOUN'))],
#  [('and', 'CONJ'), (('restructuring', 'NOUN'), ('restructuring', 'VERB'))],
#  [('included', 'VERB'), (('Woolworth', '.'), ('Woolworth', 'NOUN'))],
#  [('Avon', 'NOUN'), (('Products', '.'), ('Products', 'NOUN'))],
#  [(';', '.'), (('Paramount', '.'), ('Paramount', 'NOUN'))],
#  [('and', 'CONJ'), (('Ferro', '.'), ('Ferro', 'NOUN'))],
#  [('computer', 'NOUN'), (('errors', '.'), ('errors', 'NOUN'))],
#  [('are', 'VERB'), (('betting', '.'), ('betting', 'VERB'))],
#  [('health', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('care', 'NOUN'), (('providers', '.'), ('providers', 'NOUN'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('of', 'ADP'), (('pregnant', '.'), ('pregnant', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('In', 'ADP'), (('Syracuse', '.'), ('Syracuse', 'NOUN'))],
#  [(',', '.'), (('DyDee', '.'), ('DyDee', 'NOUN'))],
#  [('marketing', 'NOUN'), (('push', 'VERB'), ('push', 'NOUN'))],
#  [('push', 'NOUN'), (('stresses', '.'), ('stresses', 'VERB'))],
#  [('environmental', 'ADJ'), (('awareness', '.'), ('awareness', 'NOUN'))],
#  [('vehicles', 'NOUN'), (('classed', '.'), ('classed', 'VERB'))],
#  [('carry', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('than', 'ADP'), (('cargo', '.'), ('cargo', 'NOUN'))],
#  [('and', 'CONJ'), (('therefore', '.'), ('therefore', 'ADV'))],
#  [('Since', 'ADP'), (('chalk', '.'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', '.'), ('touched', 'VERB'))],
#  [('touched', 'VERB'), (('slate', '.'), ('slate', 'NOUN'))],
#  [(',', '.'), (('schoolchildren', '.'), ('schoolchildren', 'NOUN'))],
#  [("n't", 'ADV'), (('segmenting', '.'), ('segmenting', 'VERB'))],
#  [('been', 'VERB'), (('spending', 'NOUN'), ('spending', 'VERB'))],
#  [('their', 'PRON'), (('images', '.'), ('images', 'NOUN'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [("'s", 'PRT'), (('perceptions', '.'), ('perceptions', 'NOUN'))],
#  [('The', 'DET'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [("'s", 'PRT'), (('mediocre', '.'), ('mediocre', 'ADJ'))],
#  [('U.S.', 'NOUN'), (('Assistant', '.'), ('Assistant', 'NOUN'))],
#  [('David', 'NOUN'), (('Mulford', '.'), ('Mulford', 'NOUN'))],
#  [('.', '.'), (('4', 'NUM'), ('4', 'X'))],
#  [('a', 'DET'), (('diamond', '.'), ('diamond', 'NOUN'))],
#  [('diamond', 'NOUN'), (('necklace', '.'), ('necklace', 'NOUN'))],
#  [('the', 'DET'), (('particulars', '.'), ('particulars', 'NOUN'))],
#  [("'s", 'PRT'), (('offense', '.'), ('offense', 'NOUN'))],
#  [('quarterly', 'ADJ'), (('refunding', 'NOUN'), ('refunding', 'VERB'))],
#  [('kids', 'NOUN'), (('broke', '.'), ('broke', 'VERB'))],
#  [('another', 'DET'), (('drag-down', '.'), ('drag-down', 'ADJ'))],
#  [('be', 'VERB'), (('real', 'ADJ'), ('real', 'ADV'))],
#  [('a', 'DET'), (('first-rate', '.'), ('first-rate', 'ADJ'))],
#  [('.', '.'), (('Odyssey', '.'), ('Odyssey', 'NOUN'))],
#  [('Parliament', 'NOUN'), (('authorized', '.'), ('authorized', 'VERB'))],
#  [('Minister', 'NOUN'), (('Miklos', '.'), ('Miklos', 'NOUN'))],
#  [('.', '.'), (('Country', '.'), ('Country', 'NOUN'))],
#  [('funds', 'NOUN'), (('offer', 'NOUN'), ('offer', 'VERB'))],
#  [('a', 'DET'), (('taste', '.'), ('taste', 'NOUN'))],
#  [('.', '.'), (('MEDICINE', '.'), ('MEDICINE', 'NOUN'))],
#  [('MEDICINE', 'NOUN'), (('TRANSPLANT', '.'), ('TRANSPLANT', 'NOUN'))],
#  [('travel', 'NOUN'), (('prompts', '.'), ('prompts', 'VERB'))],
#  [('set', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('bilingual', '.'), ('bilingual', 'ADJ'))],
#  [('So', 'ADV'), (('Long', 'NOUN'), ('Long', 'ADJ'))],
#  [(',', '.'), (('L.A.', '.'), ('L.A.', 'NOUN'))],
#  [('final', 'ADJ'), (('headline', '.'), ('headline', 'NOUN'))],
#  [('.', '.'), (('Occidental', '.'), ('Occidental', 'NOUN'))],
#  [(',', '.'), (('shelf', '.'), ('shelf', 'NOUN'))],
#  [('*', 'X'), (('prosecuting', '.'), ('prosecuting', 'VERB'))],
#  [('0', 'X'), (('administrators', '.'), ('administrators', 'NOUN'))],
#  [('$', '.'), (('30.9', '.'), ('30.9', 'NUM'))],
#  [('alternative', 'NOUN'), (('minimum', 'ADJ'), ('minimum', 'NOUN'))],
#  [('trained', 'VERB'), (('bellringers', '.'), ('bellringers', 'NOUN'))],
#  [('only', 'ADV'), (('40,000', '.'), ('40,000', 'NUM'))],
#  [('from', 'ADP'), (('soured', '.'), ('soured', 'ADJ'))],
#  [('.', '.'), (('Second', 'NOUN'), ('Second', 'ADJ'))],
#  [('to', 'PRT'), (('unwind', '.'), ('unwind', 'VERB'))],
#  [('Board', 'NOUN'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('*EXP*-3', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('many', 'ADJ'), (('salarymen', '.'), ('salarymen', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('in', 'PRT'), (('unproductive', '.'), ('unproductive', 'ADJ'))],
#  [('unproductive', 'ADJ'), (('overtime', '.'), ('overtime', 'NOUN'))],
#  [('the', 'DET'), (('sake', '.'), ('sake', 'NOUN'))],
#  [('of', 'ADP'), (('solidarity', '.'), ('solidarity', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('so', 'ADV'), (('hierarchical', '.'), ('hierarchical', 'ADJ'))],
#  [('hierarchical', 'ADJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('that', 'ADP'), (('only', 'ADJ'), ('only', 'ADV'))],
#  [('the', 'DET'), (('assistant', 'NOUN'), ('assistant', 'ADJ'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('was', 'VERB'), (('chary', '.'), ('chary', 'ADJ'))],
#  [('short-term', 'ADJ'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('take', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('.', '.'), (('Excision', '.'), ('Excision', 'NOUN'))],
#  [('appropriations', 'NOUN'), (('riders', '.'), ('riders', 'NOUN'))],
#  [('*T*-1', 'X'), (('trespass', '.'), ('trespass', 'VERB'))],
#  [('and', 'CONJ'), (('prerogative', '.'), ('prerogative', 'NOUN'))],
#  [('Ringers', 'NOUN'), (('memorize', '.'), ('memorize', 'VERB'))],
#  [('which', 'DET'), (('*T*-224', '.'), ('*T*-224', 'X'))],
#  [('have', 'VERB'), (('odd-sounding', '.'), ('odd-sounding', 'ADJ'))],
#  [('Kent', 'NOUN'), (('Treble', '.'), ('Treble', 'NOUN'))],
#  [('or', 'CONJ'), (('Grandsire', '.'), ('Grandsire', 'NOUN'))],
#  [('Grandsire', 'NOUN'), (('Caters', '.'), ('Caters', 'NOUN'))],
#  [('an', 'DET'), (('actor', '.'), ('actor', 'NOUN'))],
#  [('the', 'DET'), (('inheritor', '.'), ('inheritor', 'NOUN'))],
#  [('of', 'ADP'), (('Charlie', '.'), ('Charlie', 'NOUN'))],
#  [('a', 'DET'), (('worst-case', '.'), ('worst-case', 'ADJ'))],
#  [('forced', 'VERB'), (('*-158', '.'), ('*-158', 'X'))],
#  [('registered', 'VERB'), (('reps', '.'), ('reps', 'NOUN'))],
#  [('and', 'CONJ'), (('security-type', '.'), ('security-type', 'ADJ'))],
#  [('training', 'NOUN'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('stupid', 'ADJ'), (('mistakes', '.'), ('mistakes', 'NOUN'))],
#  [('the', 'DET'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('totaled', 'VERB'), (('9,118', '.'), ('9,118', 'NUM'))],
#  [(',', '.'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('from', 'ADP'), (('4,645', '.'), ('4,645', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('from', 'ADP'), (('917', '.'), ('917', 'NUM'))],
#  [('Constitution', 'NOUN'), (('authorizes', '.'), ('authorizes', 'VERB'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('not', 'ADV'), (('partial', '.'), ('partial', 'ADJ'))],
#  [('.', '.'), (('Pan', '.'), ('Pan', 'NOUN'))],
#  [('Pan', 'NOUN'), (('Am', '.'), ('Am', 'VERB'))],
#  [('has', 'VERB'), (('subpoenaed', '.'), ('subpoenaed', 'VERB'))],
#  [('the', 'DET'), (('CIA', '.'), ('CIA', 'NOUN'))],
#  [('and', 'CONJ'), (('FBI', '.'), ('FBI', 'NOUN'))],
#  [('a', 'DET'), (('bomb', '.'), ('bomb', 'NOUN'))],
#  [('been', 'VERB'), (('planted', '.'), ('planted', 'VERB'))],
#  [('*-2', 'X'), (('aboard', '.'), ('aboard', 'ADP'))],
#  [('jet', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-3', 'X'), (('exploded', '.'), ('exploded', 'VERB'))],
#  [('over', 'ADP'), (('Scotland', '.'), ('Scotland', 'NOUN'))],
#  [('of', 'ADP'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('and', 'CONJ'), (('restructurings', '.'), ('restructurings', 'NOUN'))],
#  [('.', '.'), (('Light', '.'), ('Light', 'NOUN'))],
#  [('Mr.', 'NOUN'), (('Gartner', '.'), ('Gartner', 'NOUN'))],
#  [('Daily', 'NOUN'), (('Tribune', '.'), ('Tribune', 'NOUN'))],
#  [('in', 'ADP'), (('Ames', '.'), ('Ames', 'NOUN'))],
#  [('from', 'ADP'), (('unfounded', '.'), ('unfounded', 'ADJ'))],
#  [('unfounded', 'ADJ'), (('interrogation', '.'), ('interrogation', 'NOUN'))],
#  [('to', 'PRT'), (('397', '.'), ('397', 'NUM'))],
#  [('fellow', 'ADJ'), (('Texan', '.'), ('Texan', 'NOUN'))],
#  [('Sen.', 'NOUN'), (('Lloyd', '.'), ('Lloyd', 'NOUN'))],
#  [('Lloyd', 'NOUN'), (('Bentsen', '.'), ('Bentsen', 'NOUN'))],
#  [('to', 'PRT'), (('highlight', '.'), ('highlight', 'VERB'))],
#  [('who', 'PRON'), (('*T*-185', '.'), ('*T*-185', 'X'))],
#  [('No', 'DET'), (('one', 'NUM'), ('one', 'PRON'))],
#  [('the', 'DET'), (('snaking', '.'), ('snaking', 'VERB'))],
#  [('*-2', 'X'), (('muffled', '.'), ('muffled', 'VERB'))],
#  [('tried', 'VERB'), (('packaging', 'NOUN'), ('packaging', 'VERB'))],
#  [('packaging', 'VERB'), (('before', 'ADP'), ('before', 'ADV'))],
#  [('.', '.'), (('Image', '.'), ('Image', 'NOUN'))],
#  [('what', 'PRON'), (('*T*-170', '.'), ('*T*-170', 'X'))],
#  [('what', 'PRON'), (('*T*-171', '.'), ('*T*-171', 'X'))],
#  [('forced', 'VERB'), (('*-100', '.'), ('*-100', 'X'))],
#  [('*T*-2', 'X'), (('costs', 'NOUN'), ('costs', 'VERB'))],
#  [('the', 'DET'), (('caller', '.'), ('caller', 'NOUN'))],
#  [('a', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('by', 'ADP'), (('celebrity', '.'), ('celebrity', 'NOUN'))],
#  [('celebrity', 'NOUN'), (('chatter', '.'), ('chatter', 'NOUN'))],
#  [(',', '.'), (('horoscopes', '.'), ('horoscopes', 'NOUN'))],
#  [('reached', 'VERB'), (('*-120', '.'), ('*-120', 'X'))],
#  [('have', 'VERB'), (('reaped', '.'), ('reaped', 'VERB'))],
#  [('hefty', 'ADJ'), (('chunk', '.'), ('chunk', 'NOUN'))],
#  [('their', 'PRON'), (('biannual', '.'), ('biannual', 'ADJ'))],
#  [('biannual', 'ADJ'), (('powwow', '.'), ('powwow', 'NOUN'))],
#  [('manufacturing', 'VERB'), (('titans', '.'), ('titans', 'NOUN'))],
#  [('typically', 'ADV'), (('jet', 'NOUN'), ('jet', 'VERB'))],
#  [('the', 'DET'), (('sunny', '.'), ('sunny', 'ADJ'))],
#  [('sunny', 'ADJ'), (('confines', '.'), ('confines', 'NOUN'))],
#  [('and', 'CONJ'), (('Hot', 'ADJ'), ('Hot', 'NOUN'))],
#  [('Andrew', 'NOUN'), (('Derel', '.'), ('Derel', 'NOUN'))],
#  [('Derel', 'NOUN'), (('Adams', '.'), ('Adams', 'NOUN'))],
#  [(',', '.'), (('Killeen', '.'), ('Killeen', 'NOUN'))],
#  [('Francis', 'NOUN'), (('Angier', '.'), ('Angier', 'NOUN'))],
#  [(',', '.'), (('Reddington', '.'), ('Reddington', 'NOUN'))],
#  [('Reddington', 'NOUN'), (('Shores', '.'), ('Shores', 'NOUN'))],
#  [(',', '.'), (('Arlington', '.'), ('Arlington', 'NOUN'))],
#  [('William', 'NOUN'), (('Stirlen', '.'), ('Stirlen', 'NOUN'))],
#  [(',', '.'), (('Arlington', '.'), ('Arlington', 'NOUN'))],
#  [('W.', 'NOUN'), (('Bonnell', '.'), ('Bonnell', 'NOUN'))],
#  [('J.', 'NOUN'), (('Boorse', '.'), ('Boorse', 'NOUN'))],
#  [(',', '.'), (('Horsham', '.'), ('Horsham', 'NOUN'))],
#  [('David', 'NOUN'), (('Chiodo', '.'), ('Chiodo', 'NOUN'))],
#  [(';', '.'), (('Camille', '.'), ('Camille', 'NOUN'))],
#  [('Camille', 'NOUN'), (('Chafic', '.'), ('Chafic', 'NOUN'))],
#  [('Chafic', 'NOUN'), (('Cotran', '.'), ('Cotran', 'NOUN'))],
#  [('.', '.'), (('Ketchum', '.'), ('Ketchum', 'NOUN'))],
#  [('acquired', 'VERB'), (('Braun', '.'), ('Braun', 'NOUN'))],
#  [('Angeles', 'NOUN'),
#   (('investor-relations', '.'), ('investor-relations', 'NOUN'))],
#  [('and', 'CONJ'),
#   (('marketing-communications', '.'), ('marketing-communications', 'NOUN'))],
#  [('is', 'VERB'), (('laying', '.'), ('laying', 'VERB'))],
#  [('laying', 'VERB'), (('off', 'ADP'), ('off', 'PRT'))],
#  [('average', 'ADJ'), (('8.19', '.'), ('8.19', 'NUM'))],
#  [('from', 'ADP'), (('8.22', '.'), ('8.22', 'NUM'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('average', 'ADJ'), (('8.53', '.'), ('8.53', 'NUM'))],
#  [('from', 'ADP'), (('8.56', '.'), ('8.56', 'NUM'))],
#  [('He', 'PRON'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('antitrust', 'ADJ'), (('staffs', '.'), ('staffs', 'NOUN'))],
#  [('*-87', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('off', 'PRT'), (('drastically', '.'), ('drastically', 'ADV'))],
#  [('The', 'DET'), (('interactions', '.'), ('interactions', 'NOUN'))],
#  [('*-1', 'X'), (('defying', '.'), ('defying', 'VERB'))],
#  [('sweeping', 'ADJ'),
#   (('generalizations', '.'), ('generalizations', 'NOUN'))],
#  [('*-2', 'X'), (('bundling', '.'), ('bundling', 'VERB'))],
#  [('.', '.'), (('GOODY', '.'), ('GOODY', 'NOUN'))],
#  [('GOODY', 'NOUN'), (('PRODUCTS', '.'), ('PRODUCTS', 'NOUN'))],
#  [('from', 'ADP'), (('11.5', '.'), ('11.5', 'NUM'))],
#  [('who', 'PRON'), (('*T*-203', '.'), ('*T*-203', 'X'))],
#  [('replace', 'VERB'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('British', 'NOUN'), (('Airways', '.'), ('Airways', 'NOUN'))],
#  [('.', '.'), (('FIRST', '.'), ('FIRST', 'NUM'))],
#  [('FIRST', 'NUM'), (('CAMPAIGN', '.'), ('CAMPAIGN', 'NOUN'))],
#  [('largely', 'ADV'), (('hugging', '.'), ('hugging', 'VERB'))],
#  [('might', 'VERB'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [('expensive', 'ADJ'), (('cleanup', '.'), ('cleanup', 'NOUN'))],
#  [('or', 'CONJ'), (('burn', '.'), ('burn', 'VERB'))],
#  [('burn', 'VERB'), (('cleaner-burning', '.'), ('cleaner-burning', 'ADJ'))],
#  [('cleaner-burning', 'ADJ'), (('fuels', '.'), ('fuels', 'NOUN'))],
#  [('the', 'DET'), (('rigors', '.'), ('rigors', 'NOUN'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('its', 'PRON'), (('glory', '.'), ('glory', 'NOUN'))],
#  [('had', 'VERB'), (('faded', '.'), ('faded', 'VERB'))],
#  [('the', 'DET'), (('yellow', '.'), ('yellow', 'ADJ'))],
#  [('yellow', 'ADJ'), (('bricks', '.'), ('bricks', 'NOUN'))],
#  [('broad', 'ADJ'), (('facade', '.'), ('facade', 'NOUN'))],
#  [('.', '.'), (('Pressures', '.'), ('Pressures', 'NOUN'))],
#  [('were', 'VERB'), (('corrected', '.'), ('corrected', 'VERB'))],
#  [('on', 'ADP'), (('50.1', '.'), ('50.1', 'NUM'))],
#  [('not', 'ADV'), (('profit', 'VERB'), ('profit', 'NOUN'))],
#  [('.', '.'), (('DIAPER', '.'), ('DIAPER', 'NOUN'))],
#  [('DIAPER', 'NOUN'), (('SERVICES', '.'), ('SERVICES', 'NOUN'))],
#  [('a', 'DET'), (('comeback', '.'), ('comeback', 'NOUN'))],
#  [('amid', 'ADP'), (('growing', 'ADJ'), ('growing', 'VERB'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('of', 'ADP'), (('American-made', '.'), ('American-made', 'ADJ'))],
#  [('the', 'DET'), (('Natural', '.'), ('Natural', 'NOUN'))],
#  [('times', 'NOUN'), (('lengthen', '.'), ('lengthen', 'VERB'))],
#  [('``', '.'), (('minority-owned', '.'), ('minority-owned', 'ADJ'))],
#  [('a', 'DET'), (('blighted', '.'), ('blighted', 'ADJ'))],
#  [('*', 'X'), (('famous', '.'), ('famous', 'ADJ'))],
#  [('by', 'ADP'), (('Jimmy', '.'), ('Jimmy', 'NOUN'))],
#  [('with', 'ADP'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [("'s", 'PRT'), (('offerings', '.'), ('offerings', 'NOUN'))],
#  [('and', 'CONJ'), (('pricings', '.'), ('pricings', 'NOUN'))],
#  [('and', 'CONJ'), (('non-U.S.', '.'), ('non-U.S.', 'NOUN'))],
#  [('and', 'CONJ'), (('syndicate', '.'), ('syndicate', 'NOUN'))],
#  [('The', 'DET'), (('Continental', '.'), ('Continental', 'NOUN'))],
#  [('Continental', 'NOUN'), (('Baking', '.'), ('Baking', 'NOUN'))],
#  [('on', 'ADP'), (('bread', '.'), ('bread', 'NOUN'))],
#  [('trend', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('first', 'ADJ'), (('stirrings', '.'), ('stirrings', 'NOUN'))],
#  [(',', '.'), (('accelerated', 'ADJ'), ('accelerated', 'VERB'))],
#  [('the', 'DET'), (('dawn', '.'), ('dawn', 'NOUN'))],
#  [('a', 'DET'), (('sometimes-tawdry', '.'), ('sometimes-tawdry', 'ADJ'))],
#  [('$', '.'), (('9.3', '.'), ('9.3', 'NUM'))],
#  [('House', 'NOUN'), (('Majority', '.'), ('Majority', 'NOUN'))],
#  [('Majority', 'NOUN'), (('Whip', '.'), ('Whip', 'NOUN'))],
#  [(',', '.'), (('Pa', '.'), ('Pa', 'NOUN'))],
#  [('to', 'PRT'), (('English-speaking', '.'), ('English-speaking', 'ADJ'))],
#  [('and', 'CONJ'), (('Barbados', '.'), ('Barbados', 'NOUN'))],
#  [('.', '.'), (('Hours', '.'), ('Hours', 'NOUN'))],
#  [(',', '.'), (('representatives', '.'), ('representatives', 'NOUN'))],
#  [('*-1', 'X'), (('recruiting', '.'), ('recruiting', 'VERB'))],
#  [('quite', 'ADV'), (('content', 'NOUN'), ('content', 'ADJ'))],
#  [('that', 'ADP'), (('durable-goods', '.'), ('durable-goods', 'NOUN'))],
#  [('the', 'DET'), (('tort', '.'), ('tort', 'NOUN'))],
#  [('a', 'DET'), (('lousy', '.'), ('lousy', 'ADJ'))],
#  [('*T*-1', 'X'), (('anyway', '.'), ('anyway', 'ADV'))],
#  [('and', 'CONJ'), (('contingency-fee', '.'), ('contingency-fee', 'ADJ'))],
#  [('cut', 'NOUN'), (('either', 'CONJ'), ('either', 'DET'))],
#  [('.', '.'), (('Preliminary', '.'), ('Preliminary', 'ADJ'))],
#  [('Preliminary', 'ADJ'), (('tallies', '.'), ('tallies', 'NOUN'))],
#  [('a', 'DET'), (('cloud', '.'), ('cloud', 'NOUN'))],
#  [("'s", 'PRT'), (('export-oriented', '.'), ('export-oriented', 'ADJ'))],
#  [('current', 'ADJ'), (('duo', '.'), ('duo', 'NOUN'))],
#  [('Its', 'PRON'), (('entrenched', '.'), ('entrenched', 'VERB'))],
#  [('fighting', 'VERB'), (('tooth', '.'), ('tooth', 'NOUN'))],
#  [('and', 'CONJ'), (('nail', '.'), ('nail', 'NOUN'))],
#  [('.', '.'), (('Compound', '.'), ('Compound', 'NOUN'))],
#  [('assume', 'VERB'), (('reinvestment', '.'), ('reinvestment', 'NOUN'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('push', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('political', 'ADJ'), (('insider', '.'), ('insider', 'NOUN'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('to', 'PRT'), (('present', 'ADJ'), ('present', 'VERB'))],
#  [('to', 'PRT'), (('appease', '.'), ('appease', 'VERB'))],
#  [('appease', 'VERB'), (('Midwestern', 'NOUN'), ('Midwestern', 'ADJ'))],
#  [('from', 'ADP'), (('high-polluting', '.'), ('high-polluting', 'ADJ'))],
#  [('on', 'ADP'), (('cost-sharing', 'ADJ'), ('cost-sharing', 'NOUN'))],
#  [(':', '.'), (('Crude', '.'), ('Crude', 'ADJ'))],
#  [('but', 'CONJ'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('be', 'VERB'), (('no', 'DET'), ('no', 'ADV'))],
#  [('of', 'ADP'), (('bankrupt', '.'), ('bankrupt', 'ADJ'))],
#  [('to', 'PRT'), (('form', 'NOUN'), ('form', 'VERB'))],
#  [('complete', 'VERB'), (('most', 'ADV'), ('most', 'ADJ'))],
#  [('Donald', 'NOUN'), (('Anderson', '.'), ('Anderson', 'NOUN'))],
#  [('a', 'DET'), (('59-year-old', '.'), ('59-year-old', 'ADJ'))],
#  [('``', '.'), (('fluctuations', '.'), ('fluctuations', 'NOUN'))],
#  [('the', 'DET'), (('heebie-jeebies', '.'), ('heebie-jeebies', 'NOUN'))],
#  [('see', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('point', 'VERB'), ('point', 'NOUN'))],
#  [('*', 'X'), (('outlawing', '.'), ('outlawing', 'VERB'))],
#  [('Neil', 'NOUN'), (('Kuvin', '.'), ('Kuvin', 'NOUN'))],
#  [('of', 'ADP'), (('WHAS', '.'), ('WHAS', 'NOUN'))],
#  [('do', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('a', 'DET'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('*-1', 'X'), (('Crude', '.'), ('Crude', 'ADJ'))],
#  [('triggered', 'VERB'), (('explosive', '.'), ('explosive', 'ADJ'))],
#  [('in', 'ADP'), (('desktop', '.'), ('desktop', 'NOUN'))],
#  [('Gulf', 'NOUN'), (('rebuffed', '.'), ('rebuffed', 'VERB'))],
#  [('would', 'VERB'), (('study', 'NOUN'), ('study', 'VERB'))],
#  [('Chinese', 'ADJ'), (('dissident', '.'), ('dissident', 'NOUN'))],
#  [('Fang', 'NOUN'), (('Lizhi', '.'), ('Lizhi', 'NOUN'))],
#  [('Li', 'NOUN'), (('Shuxian', '.'), ('Shuxian', 'NOUN'))],
#  [('took', 'VERB'), (('refuge', '.'), ('refuge', 'NOUN'))],
#  [('.', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [('figures', 'NOUN'), (('contrast', 'NOUN'), ('contrast', 'VERB'))],
#  [("'s", 'PRT'), (('F.W.', '.'), ('F.W.', 'NOUN'))],
#  [('a', 'DET'), (('raise', 'VERB'), ('raise', 'NOUN'))],
#  [('in', 'ADP'), (('replacement-car', '.'), ('replacement-car', 'NOUN'))],
#  [('replacement-car', 'NOUN'), (('rentals', '.'), ('rentals', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', '.'), ('accidents', 'NOUN'))],
#  [('$', '.'), (('46.1', '.'), ('46.1', 'NUM'))],
#  [('$', '.'), (('1.85', '.'), ('1.85', 'NUM'))],
#  [('$', '.'), (('1.85', '.'), ('1.85', 'NUM'))],
#  [('and', 'CONJ'), (('automated', '.'), ('automated', 'VERB'))],
#  [('trading', 'NOUN'), (('threatens', '.'), ('threatens', 'VERB'))],
#  [('make', 'VERB'), (('dinosaurs', '.'), ('dinosaurs', 'NOUN'))],
#  [('Board', 'NOUN'), (('stock-specialist', '.'), ('stock-specialist', 'ADJ'))],
#  [('firms', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-255', '.'), ('*T*-255', 'X'))],
#  [('-RRB-', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('a', 'DET'), (('Hawaiian', '.'), ('Hawaiian', 'ADJ'))],
#  [('$', '.'), (('234.4', '.'), ('234.4', 'NUM'))],
#  [('squeezed', 'VERB'), (('*-122', '.'), ('*-122', 'X'))],
#  [('the', 'DET'), (('mid-1970s', '.'), ('mid-1970s', 'NUM'))],
#  [('who', 'PRON'), (('*T*-130', '.'), ('*T*-130', 'X'))],
#  [('who', 'PRON'), (('*T*-131', '.'), ('*T*-131', 'X'))],
#  [('.', '.'), (('W.N.', '.'), ('W.N.', 'NOUN'))],
#  [('of', 'ADP'), (('Georgetown', '.'), ('Georgetown', 'NOUN'))],
#  [('William', 'NOUN'), (('N.', '.'), ('N.', 'NOUN'))],
#  [('of', 'ADP'), (('Georgetown', '.'), ('Georgetown', 'NOUN'))],
#  [('about', 'ADP'), (('jurisdictional', '.'), ('jurisdictional', 'ADJ'))],
#  [('which', 'DET'), (('*T*-217', '.'), ('*T*-217', 'X'))],
#  [('*T*-217', 'X'), (('uses', 'NOUN'), ('uses', 'VERB'))],
#  [('trend', 'NOUN'), (('improves', '.'), ('improves', 'VERB'))],
#  [('.', '.'), (('Unfortunately', '.'), ('Unfortunately', 'ADV'))],
#  [('London', 'NOUN'), (('serves', '.'), ('serves', 'VERB'))],
#  [('a', 'DET'), (('conduit', '.'), ('conduit', 'NOUN'))],
#  [('unit', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-108', '.'), ('*T*-108', 'X'))],
#  [('which', 'DET'), (('*T*-109', '.'), ('*T*-109', 'X'))],
#  [('*T*-109', 'X'), (('later', 'ADJ'), ('later', 'ADV'))],
#  [('Treasury', 'NOUN'), (('estimates', 'NOUN'), ('estimates', 'VERB'))],
#  [('it', 'PRON'), (('decides', '.'), ('decides', 'VERB'))],
#  [('to', 'PRT'), (('aim', 'NOUN'), ('aim', 'VERB'))],
#  [('*T*-2', 'X'), (('Kelli', '.'), ('Kelli', 'NOUN'))],
#  [('Kelli', 'NOUN'), (('Green', '.'), ('Green', 'NOUN'))],
#  [('Greenville', 'NOUN'), (('senior', 'ADJ'), ('senior', 'NOUN'))],
#  [('James', 'NOUN'), (('Goldsmith', '.'), ('Goldsmith', 'NOUN'))],
#  [('Goldsmith', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [("'s", 'PRT'), (('Hoylake', '.'), ('Hoylake', 'NOUN'))],
#  [('Hoylake', 'NOUN'), (('Investments', '.'), ('Investments', 'NOUN'))],
#  [('to', 'PRT'), (('753', '.'), ('753', 'NUM'))],
#  [('that', 'ADP'), (('Hoylake', '.'), ('Hoylake', 'NOUN'))],
#  [('will', 'VERB'), (('sweeten', '.'), ('sweeten', 'VERB'))],
#  [('The', 'DET'), (('downgrading', '.'), ('downgrading', 'NOUN'))],
#  [('sent', 'VERB'), (('shivers', '.'), ('shivers', 'NOUN'))],
#  [('``', '.'), (('Invariably', '.'), ('Invariably', 'ADV'))],
#  [(',', '.'), (('Coche-Dury', '.'), ('Coche-Dury', 'NOUN'))],
#  [('1987', 'NUM'),
#   (('Corton-Charlemagne', '.'), ('Corton-Charlemagne', 'NOUN'))],
#  [('*', 'X'), (('tapping', '.'), ('tapping', 'VERB'))],
#  [('air', 'NOUN'), (('cargo', '.'), ('cargo', 'NOUN'))],
#  [('of', 'ADP'), (('Tiger', '.'), ('Tiger', 'NOUN'))],
#  [('S.', 'NOUN'), (('Jenkins', '.'), ('Jenkins', 'NOUN'))],
#  [('IRS', 'NOUN'), (('rarely', '.'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', '.'), ('acted', 'VERB'))],
#  [('and', 'CONJ'), (('share', 'NOUN'), ('share', 'VERB'))],
#  [('the', 'DET'), (('compassion', '.'), ('compassion', 'NOUN'))],
#  [('to', 'PRT'), (('offer', 'NOUN'), ('offer', 'VERB'))],
#  [('of', 'ADP'), (('Solomonic', '.'), ('Solomonic', 'ADJ'))],
#  [('.', '.'), (('Financially', '.'), ('Financially', 'ADV'))],
#  [('its', 'PRON'), (('moments', '.'), ('moments', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-91', '.'), ('*T*-91', 'X'))],
#  [('a', 'DET'), (('grandstander', '.'), ('grandstander', 'NOUN'))],
#  [('.', '.'), (('Defending', '.'), ('Defending', 'VERB'))],
#  [('their', 'PRON'), (('ramparts', '.'), ('ramparts', 'NOUN'))],
#  [(',', '.'), (('stock-picking', '.'), ('stock-picking', 'ADJ'))],
#  [(',', '.'), (('tens', '.'), ('tens', 'NOUN'))],
#  [('the', 'DET'), (('clannish', '.'), ('clannish', 'ADJ'))],
#  [(',', '.'), (('Colonsville', '.'), ('Colonsville', 'NOUN'))],
#  [('Gerard', 'NOUN'), (('Dompierre', '.'), ('Dompierre', 'NOUN'))],
#  [(',', '.'), (('Valrico', '.'), ('Valrico', 'NOUN'))],
#  [('$', '.'), (('16,072', '.'), ('16,072', 'NUM'))],
#  [(';', '.'), (('Marion', '.'), ('Marion', 'NOUN'))],
#  [('Marion', 'NOUN'), (('Stewart', '.'), ('Stewart', 'NOUN'))],
#  [('Stewart', 'NOUN'), (('Spitler', '.'), ('Spitler', 'NOUN'))],
#  [('$', '.'), (('18,444', '.'), ('18,444', 'NUM'))],
#  [('who', 'PRON'), (('*T*-95', '.'), ('*T*-95', 'X'))],
#  [(',', '.'), (('net', 'ADJ'), ('net', 'NOUN'))],
#  [('$', '.'), (('306', '.'), ('306', 'NUM'))],
#  [('Younkers', 'NOUN'), (('rang', '.'), ('rang', 'VERB'))],
#  [('rang', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('$', '.'), (('313', '.'), ('313', 'NUM'))],
#  [('New', 'NOUN'), (('Brunswick', '.'), ('Brunswick', 'NOUN'))],
#  [('declined', 'VERB'), (('comment', 'VERB'), ('comment', 'NOUN'))],
#  [('and', 'CONJ'), (('clothing', '.'), ('clothing', 'NOUN'))],
#  [('interest', 'NOUN'), (('expense', '.'), ('expense', 'NOUN'))],
#  [('expense', 'NOUN'), (('exceeds', '.'), ('exceeds', 'VERB'))],
#  [('big', 'ADJ'), (('chunk', '.'), ('chunk', 'NOUN'))],
#  [('produce', 'VERB'), (('consistent', '.'), ('consistent', 'ADJ'))],
#  [('has', 'VERB'), (('wedded', '.'), ('wedded', 'VERB'))],
#  [('which', 'DET'), (('*T*-213', '.'), ('*T*-213', 'X'))],
#  [('*-2', 'X'), (('sacrificing', '.'), ('sacrificing', 'VERB'))],
#  [('sale', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-140', '.'), ('*T*-140', 'X'))],
#  [('which', 'DET'), (('*T*-173', '.'), ('*T*-173', 'X'))],
#  [('exercised', 'VERB'), (('*-104', '.'), ('*-104', 'X'))],
#  [('of', 'ADP'), (('unfilled', '.'), ('unfilled', 'ADJ'))],
#  [('rose', 'VERB'), (('0.5', '.'), ('0.5', 'NUM'))],
#  [('$', '.'), (('497.34', '.'), ('497.34', 'NUM'))],
#  [('These', 'DET'), (('vertically', '.'), ('vertically', 'ADV'))],
#  [('integrated', 'VERB'), (('combines', 'VERB'), ('combines', 'NOUN'))],
#  [('their', 'PRON'), (('start', 'VERB'), ('start', 'NOUN'))],
#  [("'s", 'PRT'), (('feudal', '.'), ('feudal', 'ADJ'))],
#  [(',', '.'), (('deal', 'NOUN'), ('deal', 'VERB'))],
#  [('deal', 'VERB'), (('globally', '.'), ('globally', 'ADV'))],
#  [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('quite', 'ADV'), (('brilliantly', '.'), ('brilliantly', 'ADV'))],
#  [('*EXP*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('something', 'NOUN'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('that', 'ADV'), (('comprehensive', '.'), ('comprehensive', 'ADJ'))],
#  [('are', 'VERB'), (('reviewing', '.'), ('reviewing', 'VERB'))],
#  [('The', 'DET'),
#   (('financial-services', 'ADJ'), ('financial-services', 'NOUN'))],
#  [('.', '.'), (('Mostly', '.'), ('Mostly', 'ADV'))],
#  [('to', 'PRT'), (('self-esteem', '.'), ('self-esteem', 'NOUN'))],
#  [('self-esteem', 'NOUN'), (('that', 'DET'), ('that', 'ADP'))],
#  [('an', 'DET'), (('inauspicious', '.'), ('inauspicious', 'ADJ'))],
#  [('inauspicious', 'ADJ'), (('beginning', 'VERB'), ('beginning', 'NOUN'))],
#  [('0', 'X'), (('greedy', '.'), ('greedy', 'ADJ'))],
#  [('market', 'NOUN'), (('manipulators', '.'), ('manipulators', 'NOUN'))],
#  [('a', 'DET'), (('shambles', '.'), ('shambles', 'NOUN'))],
#  [("'s", 'PRT'), (('free-enterprise', '.'), ('free-enterprise', 'NOUN'))],
#  [('big', 'ADJ'), (('gambling', '.'), ('gambling', 'NOUN'))],
#  [('gambling', 'NOUN'), (('den', '.'), ('den', 'NOUN'))],
#  [('the', 'DET'), (('odds', '.'), ('odds', 'NOUN'))],
#  [('heavily', 'ADV'), (('stacked', '.'), ('stacked', 'VERB'))],
#  [('The', 'DET'), (('record', 'NOUN'), ('record', 'ADJ'))],
#  [('$', '.'), (('550,000', '.'), ('550,000', 'NUM'))],
#  [('to', 'PRT'), (('hunker', '.'), ('hunker', 'VERB'))],
#  [('hunker', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('$', '.'), (('47.5', '.'), ('47.5', 'NUM'))],
#  [('to', 'PRT'), (('end', 'NOUN'), ('end', 'VERB'))],
#  [('$', '.'), (('38.375', '.'), ('38.375', 'NUM'))],
#  [('achieve', 'VERB'), (('near-record', '.'), ('near-record', 'ADJ'))]]

# %%
# tagging the validation sentences using the modified Viterbi
start = time.time()
tagged_seq = ViterbiNew(val_tagged_words)
end = time.time()
difference = end-start
print ("Time Taken with modified Viterbi on Validation Data ::", difference)
# accuracy
check = [i for i, j in zip(tagged_seq, val_run_base) if i == j] 
accuracy_new = len(check)/len(tagged_seq)
print ("Accuracy ::", accuracy_new)
incorrect_tagged_cases_new = [[val_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, val_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases_new
# Out:
# Correcting ::  W.D.  to NOUN when prev tag is  .
# Correcting ::  refuses  to NOUN when prev tag is  .
# Correcting ::  Woolworth  to NOUN when prev tag is  VERB
# Correcting ::  Products  to NOUN when prev tag is  NOUN
# Correcting ::  Paramount  to NOUN when prev tag is  .
# Correcting ::  Ferro  to NOUN when prev tag is  CONJ
# Correcting ::  errors  to NOUN when prev tag is  NOUN
# Correcting ::  betting  to NOUN when prev tag is  VERB
# Correcting ::  providers  to NOUN when prev tag is  VERB
# Correcting ::  pregnant  to NOUN when prev tag is  ADP
# Correcting ::  Syracuse  to NOUN when prev tag is  ADP
# Correcting ::  DyDee  to NOUN when prev tag is  .
# Correcting ::  stresses  to NOUN when prev tag is  VERB
# Correcting ::  awareness  to NOUN when prev tag is  ADJ
# Correcting ::  classed  to NOUN when prev tag is  NOUN
# Correcting ::  cargo  to NOUN when prev tag is  ADP
# Correcting ::  therefore  to NOUN when prev tag is  CONJ
# Correcting ::  chalk  to NOUN when prev tag is  ADP
# Correcting ::  touched  to NOUN when prev tag is  ADJ
# Correcting ::  slate  to NOUN when prev tag is  NOUN
# Correcting ::  schoolchildren  to NOUN when prev tag is  .
# Correcting ::  segmenting  to NOUN when prev tag is  ADV
# Correcting ::  images  to NOUN when prev tag is  PRON
# Correcting ::  perceptions  to NOUN when prev tag is  PRT
# Correcting ::  mediocre  to NOUN when prev tag is  PRT
# Correcting ::  Assistant  to NOUN when prev tag is  NOUN
# Correcting ::  Mulford  to NOUN when prev tag is  NOUN
# Correcting ::  diamond  to NOUN when prev tag is  DET
# Correcting ::  necklace  to NOUN when prev tag is  NOUN
# Correcting ::  particulars  to NOUN when prev tag is  DET
# Correcting ::  offense  to NOUN when prev tag is  PRT
# Correcting ::  broke  to NOUN when prev tag is  NOUN
# Correcting ::  drag-down  to NOUN when prev tag is  DET
# Correcting ::  first-rate  to NOUN when prev tag is  DET
# Correcting ::  Odyssey  to NOUN when prev tag is  .
# Correcting ::  authorized  to NOUN when prev tag is  NOUN
# Correcting ::  Miklos  to NOUN when prev tag is  NOUN
# Correcting ::  Country  to NOUN when prev tag is  .
# Correcting ::  taste  to NOUN when prev tag is  DET
# Correcting ::  MEDICINE  to NOUN when prev tag is  .
# Correcting ::  TRANSPLANT  to NOUN when prev tag is  NOUN
# Correcting ::  prompts  to NOUN when prev tag is  NOUN
# Correcting ::  bilingual  to NOUN when prev tag is  DET
# Correcting ::  L.A.  to NOUN when prev tag is  .
# Correcting ::  headline  to NOUN when prev tag is  ADJ
# Correcting ::  Occidental  to NOUN when prev tag is  .
# Correcting ::  shelf  to NOUN when prev tag is  .
# Correcting ::  prosecuting  to NOUN when prev tag is  X
# Correcting ::  administrators  to NOUN when prev tag is  X
# Correcting ::  30.9  to NUM
# Correcting ::  bellringers  to NOUN when prev tag is  VERB
# Correcting ::  40,000  to NUM
# Correcting ::  soured  to NOUN when prev tag is  ADP
# Correcting ::  unwind  to NOUN when prev tag is  PRT
# Correcting ::  salarymen  to NOUN when prev tag is  ADJ
# Correcting ::  unproductive  to NOUN when prev tag is  ADP
# Correcting ::  overtime  to NOUN when prev tag is  NOUN
# Correcting ::  sake  to NOUN when prev tag is  DET
# Correcting ::  solidarity  to NOUN when prev tag is  ADP
# Correcting ::  hierarchical  to NOUN when prev tag is  ADV
# Correcting ::  chary  to NOUN when prev tag is  VERB
# Correcting ::  Excision  to NOUN when prev tag is  .
# Correcting ::  riders  to NOUN when prev tag is  NOUN
# Correcting ::  trespass  to NOUN when prev tag is  X
# Correcting ::  prerogative  to NOUN when prev tag is  CONJ
# Correcting ::  memorize  to NOUN when prev tag is  NOUN
# Correcting ::  *T*-224  to NOUN when prev tag is  DET
# Correcting ::  odd-sounding  to NOUN when prev tag is  VERB
# Correcting ::  Treble  to NOUN when prev tag is  NOUN
# Correcting ::  Grandsire  to NOUN when prev tag is  CONJ
# Correcting ::  Caters  to NOUN when prev tag is  NOUN
# Correcting ::  actor  to NOUN when prev tag is  DET
# Correcting ::  inheritor  to NOUN when prev tag is  DET
# Correcting ::  Charlie  to NOUN when prev tag is  ADP
# Correcting ::  worst-case  to NOUN when prev tag is  DET
# Correcting ::  *-158  to NOUN when prev tag is  VERB
# Correcting ::  reps  to NOUN when prev tag is  VERB
# Correcting ::  security-type  to NOUN when prev tag is  CONJ
# Correcting ::  mistakes  to NOUN when prev tag is  ADJ
# Correcting ::  9,118  to NUM
# Correcting ::  4,645  to NUM
# Correcting ::  917  to NUM
# Correcting ::  authorizes  to NOUN when prev tag is  NOUN
# Correcting ::  partial  to NOUN when prev tag is  ADV
# Correcting ::  Pan  to NOUN when prev tag is  .
# Correcting ::  Am  to NOUN when prev tag is  NOUN
# Correcting ::  subpoenaed  to NOUN when prev tag is  VERB
# Correcting ::  CIA  to NOUN when prev tag is  DET
# Correcting ::  FBI  to NOUN when prev tag is  CONJ
# Correcting ::  bomb  to NOUN when prev tag is  DET
# Correcting ::  planted  to NOUN when prev tag is  VERB
# Correcting ::  aboard  to NOUN when prev tag is  X
# Correcting ::  exploded  to NOUN when prev tag is  X
# Correcting ::  Scotland  to NOUN when prev tag is  ADP
# Correcting ::  restructurings  to NOUN when prev tag is  CONJ
# Correcting ::  Light  to NOUN when prev tag is  .
# Correcting ::  Gartner  to NOUN when prev tag is  NOUN
# Correcting ::  Tribune  to NOUN when prev tag is  NOUN
# Correcting ::  Ames  to NOUN when prev tag is  ADP
# Correcting ::  unfounded  to NOUN when prev tag is  ADP
# Correcting ::  interrogation  to NOUN when prev tag is  NOUN
# Correcting ::  397  to NUM
# Correcting ::  Texan  to NOUN when prev tag is  ADJ
# Correcting ::  Lloyd  to NOUN when prev tag is  NOUN
# Correcting ::  Bentsen  to NOUN when prev tag is  NOUN
# Correcting ::  highlight  to NOUN when prev tag is  PRT
# Correcting ::  *T*-185  to NOUN when prev tag is  PRON
# Correcting ::  snaking  to NOUN when prev tag is  DET
# Correcting ::  muffled  to NOUN when prev tag is  X
# Correcting ::  Image  to NOUN when prev tag is  .
# Correcting ::  *T*-170  to NOUN when prev tag is  PRON
# Correcting ::  *T*-171  to NOUN when prev tag is  PRON
# Correcting ::  *-100  to NOUN when prev tag is  VERB
# Correcting ::  caller  to NOUN when prev tag is  DET
# Correcting ::  celebrity  to NOUN when prev tag is  ADP
# Correcting ::  chatter  to NOUN when prev tag is  NOUN
# Correcting ::  horoscopes  to NOUN when prev tag is  .
# Correcting ::  *-120  to NOUN when prev tag is  VERB
# Correcting ::  reaped  to NOUN when prev tag is  VERB
# Correcting ::  chunk  to NOUN when prev tag is  ADJ
# Correcting ::  biannual  to NOUN when prev tag is  PRON
# Correcting ::  powwow  to NOUN when prev tag is  NOUN
# Correcting ::  titans  to NOUN when prev tag is  VERB
# Correcting ::  sunny  to NOUN when prev tag is  DET
# Correcting ::  confines  to NOUN when prev tag is  NOUN
# Correcting ::  Derel  to NOUN when prev tag is  NOUN
# Correcting ::  Adams  to NOUN when prev tag is  NOUN
# Correcting ::  Killeen  to NOUN when prev tag is  .
# Correcting ::  Angier  to NOUN when prev tag is  NOUN
# Correcting ::  Reddington  to NOUN when prev tag is  .
# Correcting ::  Shores  to NOUN when prev tag is  NOUN
# Correcting ::  Arlington  to NOUN when prev tag is  .
# Correcting ::  Stirlen  to NOUN when prev tag is  NOUN
# Correcting ::  Arlington  to NOUN when prev tag is  .
# Correcting ::  Bonnell  to NOUN when prev tag is  NOUN
# Correcting ::  Boorse  to NOUN when prev tag is  NOUN
# Correcting ::  Horsham  to NOUN when prev tag is  .
# Correcting ::  Chiodo  to NOUN when prev tag is  NOUN
# Correcting ::  Camille  to NOUN when prev tag is  .
# Correcting ::  Chafic  to NOUN when prev tag is  NOUN
# Correcting ::  Cotran  to NOUN when prev tag is  NOUN
# Correcting ::  Ketchum  to NOUN when prev tag is  .
# Correcting ::  Braun  to NOUN when prev tag is  VERB
# Correcting ::  investor-relations  to NOUN when prev tag is  NOUN
# Correcting ::  marketing-communications  to NOUN when prev tag is  CONJ
# Correcting ::  laying  to NOUN when prev tag is  VERB
# Correcting ::  8.19  to NOUN when prev tag is  ADJ
# Correcting ::  8.22  to NOUN when prev tag is  ADP
# Correcting ::  8.53  to NOUN when prev tag is  ADJ
# Correcting ::  8.56  to NOUN when prev tag is  ADP
# Correcting ::  staffs  to NOUN when prev tag is  ADJ
# Correcting ::  drastically  to NOUN when prev tag is  PRT
# Correcting ::  interactions  to NOUN when prev tag is  DET
# Correcting ::  defying  to NOUN when prev tag is  X
# Correcting ::  generalizations  to NOUN when prev tag is  VERB
# Correcting ::  bundling  to NOUN when prev tag is  X
# Correcting ::  GOODY  to NOUN when prev tag is  .
# Correcting ::  PRODUCTS  to NOUN when prev tag is  NOUN
# Correcting ::  11.5  to NUM
# Correcting ::  *T*-203  to NOUN when prev tag is  PRON
# Correcting ::  Airways  to NOUN when prev tag is  ADJ
# Correcting ::  FIRST  to NOUN when prev tag is  .
# Correcting ::  CAMPAIGN  to NOUN when prev tag is  NOUN
# Correcting ::  hugging  to NOUN when prev tag is  ADV
# Correcting ::  cleanup  to NOUN when prev tag is  ADJ
# Correcting ::  burn  to NOUN when prev tag is  CONJ
# Correcting ::  cleaner-burning  to NOUN when prev tag is  NOUN
# Correcting ::  fuels  to NOUN when prev tag is  NOUN
# Correcting ::  rigors  to NOUN when prev tag is  DET
# Correcting ::  glory  to NOUN when prev tag is  PRON
# Correcting ::  faded  to NOUN when prev tag is  VERB
# Correcting ::  yellow  to NOUN when prev tag is  DET
# Correcting ::  bricks  to NOUN when prev tag is  NOUN
# Correcting ::  facade  to NOUN when prev tag is  ADJ
# Correcting ::  Pressures  to NOUN when prev tag is  .
# Correcting ::  corrected  to NOUN when prev tag is  VERB
# Correcting ::  50.1  to NUM
# Correcting ::  DIAPER  to NOUN when prev tag is  .
# Correcting ::  SERVICES  to NOUN when prev tag is  NOUN
# Correcting ::  comeback  to NOUN when prev tag is  DET
# Correcting ::  American-made  to NOUN when prev tag is  ADP
# Correcting ::  Natural  to NOUN when prev tag is  DET
# Correcting ::  lengthen  to NOUN when prev tag is  NOUN
# Correcting ::  minority-owned  to NOUN when prev tag is  .
# Correcting ::  blighted  to NOUN when prev tag is  DET
# Correcting ::  famous  to NOUN when prev tag is  X
# Correcting ::  Jimmy  to NOUN when prev tag is  ADP
# Correcting ::  offerings  to NOUN when prev tag is  PRT
# Correcting ::  pricings  to NOUN when prev tag is  CONJ
# Correcting ::  non-U.S.  to NOUN when prev tag is  CONJ
# Correcting ::  syndicate  to NOUN when prev tag is  CONJ
# Correcting ::  Continental  to NOUN when prev tag is  DET
# Correcting ::  Baking  to NOUN when prev tag is  NOUN
# Correcting ::  bread  to NOUN when prev tag is  ADP
# Correcting ::  stirrings  to NOUN when prev tag is  ADJ
# Correcting ::  dawn  to NOUN when prev tag is  DET
# Correcting ::  sometimes-tawdry  to NOUN when prev tag is  DET
# Correcting ::  9.3  to NOUN when prev tag is  .
# Correcting ::  Majority  to NOUN when prev tag is  NOUN
# Correcting ::  Whip  to NOUN when prev tag is  NOUN
# Correcting ::  Pa  to NOUN when prev tag is  .
# Correcting ::  English-speaking  to NOUN when prev tag is  PRT
# Correcting ::  Barbados  to NOUN when prev tag is  CONJ
# Correcting ::  Hours  to NOUN when prev tag is  .
# Correcting ::  representatives  to NOUN when prev tag is  .
# Correcting ::  recruiting  to NOUN when prev tag is  X
# Correcting ::  durable-goods  to NOUN when prev tag is  ADP
# Correcting ::  tort  to NOUN when prev tag is  DET
# Correcting ::  lousy  to NOUN when prev tag is  DET
# Correcting ::  anyway  to NOUN when prev tag is  X
# Correcting ::  contingency-fee  to NOUN when prev tag is  CONJ
# Correcting ::  Preliminary  to NOUN when prev tag is  .
# Correcting ::  tallies  to NOUN when prev tag is  NOUN
# Correcting ::  cloud  to NOUN when prev tag is  DET
# Correcting ::  export-oriented  to NOUN when prev tag is  PRT
# Correcting ::  duo  to NOUN when prev tag is  ADJ
# Correcting ::  entrenched  to NOUN when prev tag is  PRON
# Correcting ::  tooth  to NOUN when prev tag is  VERB
# Correcting ::  nail  to NOUN when prev tag is  CONJ
# Correcting ::  Compound  to NOUN when prev tag is  .
# Correcting ::  reinvestment  to NOUN when prev tag is  VERB
# Correcting ::  insider  to NOUN when prev tag is  ADJ
# Correcting ::  appease  to NOUN when prev tag is  PRT
# Correcting ::  high-polluting  to NOUN when prev tag is  ADP
# Correcting ::  Crude  to NOUN when prev tag is  .
# Correcting ::  bankrupt  to NOUN when prev tag is  ADP
# Correcting ::  Anderson  to NOUN when prev tag is  NOUN
# Correcting ::  59-year-old  to NUM
# Correcting ::  fluctuations  to NOUN when prev tag is  .
# Correcting ::  heebie-jeebies  to NOUN when prev tag is  DET
# Correcting ::  outlawing  to NOUN when prev tag is  X
# Correcting ::  Kuvin  to NOUN when prev tag is  NOUN
# Correcting ::  WHAS  to NOUN when prev tag is  ADP
# Correcting ::  Crude  to NOUN when prev tag is  X
# Correcting ::  explosive  to NOUN when prev tag is  VERB
# Correcting ::  desktop  to NOUN when prev tag is  ADP
# Correcting ::  rebuffed  to NOUN when prev tag is  NOUN
# Correcting ::  dissident  to NOUN when prev tag is  ADJ
# Correcting ::  Lizhi  to NOUN when prev tag is  NOUN
# Correcting ::  Shuxian  to NOUN when prev tag is  NOUN
# Correcting ::  refuge  to NOUN when prev tag is  VERB
# Correcting ::  F.W.  to NOUN when prev tag is  PRT
# Correcting ::  replacement-car  to NOUN when prev tag is  ADP
# Correcting ::  rentals  to NOUN when prev tag is  NOUN
# Correcting ::  accidents  to NOUN when prev tag is  ADP
# Correcting ::  46.1  to NUM
# Correcting ::  1.85  to NOUN when prev tag is  .
# Correcting ::  1.85  to NOUN when prev tag is  .
# Correcting ::  automated  to NOUN when prev tag is  CONJ
# Correcting ::  threatens  to NOUN when prev tag is  NOUN
# Correcting ::  dinosaurs  to NOUN when prev tag is  VERB
# Correcting ::  stock-specialist  to NOUN when prev tag is  NOUN
# Correcting ::  *T*-255  to NOUN when prev tag is  ADP
# Correcting ::  Hawaiian  to NOUN when prev tag is  DET
# Correcting ::  234.4  to NUM
# Correcting ::  *-122  to NOUN when prev tag is  VERB
# Correcting ::  mid-1970s  to NOUN when prev tag is  DET
# Correcting ::  *T*-130  to NOUN when prev tag is  PRON
# Correcting ::  *T*-131  to NOUN when prev tag is  PRON
# Correcting ::  W.N.  to NOUN when prev tag is  .
# Correcting ::  Georgetown  to NOUN when prev tag is  ADP
# Correcting ::  N.  to NOUN when prev tag is  NOUN
# Correcting ::  Georgetown  to NOUN when prev tag is  ADP
# Correcting ::  jurisdictional  to NOUN when prev tag is  ADP
# Correcting ::  *T*-217  to NOUN when prev tag is  DET
# Correcting ::  improves  to NOUN when prev tag is  NOUN
# Correcting ::  Unfortunately  to NOUN when prev tag is  .
# Correcting ::  serves  to NOUN when prev tag is  NOUN
# Correcting ::  conduit  to NOUN when prev tag is  DET
# Correcting ::  *T*-108  to NOUN when prev tag is  ADP
# Correcting ::  *T*-109  to NOUN when prev tag is  DET
# Correcting ::  decides  to NOUN when prev tag is  PRON
# Correcting ::  Kelli  to NOUN when prev tag is  X
# Correcting ::  Green  to NOUN when prev tag is  NOUN
# Correcting ::  Goldsmith  to NOUN when prev tag is  NOUN
# Correcting ::  Hoylake  to NOUN when prev tag is  PRT
# Correcting ::  Investments  to NOUN when prev tag is  NOUN
# Correcting ::  753  to NUM
# Correcting ::  Hoylake  to NOUN when prev tag is  ADP
# Correcting ::  sweeten  to NOUN when prev tag is  VERB
# Correcting ::  downgrading  to NOUN when prev tag is  DET
# Correcting ::  shivers  to NOUN when prev tag is  VERB
# Correcting ::  Invariably  to NOUN when prev tag is  .
# Correcting ::  Coche-Dury  to NOUN when prev tag is  .
# Correcting ::  Corton-Charlemagne  to NOUN when prev tag is  NUM
# Correcting ::  tapping  to NOUN when prev tag is  X
# Correcting ::  cargo  to NOUN when prev tag is  NOUN
# Correcting ::  Tiger  to NOUN when prev tag is  ADP
# Correcting ::  Jenkins  to NOUN when prev tag is  NOUN
# Correcting ::  rarely  to NOUN when prev tag is  NOUN
# Correcting ::  acted  to NOUN when prev tag is  NOUN
# Correcting ::  compassion  to NOUN when prev tag is  DET
# Correcting ::  Solomonic  to NOUN when prev tag is  ADP
# Correcting ::  Financially  to NOUN when prev tag is  .
# Correcting ::  moments  to NOUN when prev tag is  PRON
# Correcting ::  *T*-91  to NOUN when prev tag is  PRON
# Correcting ::  grandstander  to NOUN when prev tag is  DET
# Correcting ::  Defending  to NOUN when prev tag is  .
# Correcting ::  ramparts  to NOUN when prev tag is  PRON
# Correcting ::  stock-picking  to NOUN when prev tag is  .
# Correcting ::  tens  to NOUN when prev tag is  .
# Correcting ::  clannish  to NOUN when prev tag is  DET
# Correcting ::  Colonsville  to NOUN when prev tag is  .
# Correcting ::  Dompierre  to NOUN when prev tag is  NOUN
# Correcting ::  Valrico  to NOUN when prev tag is  .
# Correcting ::  16,072  to NUM
# Correcting ::  Marion  to NOUN when prev tag is  .
# Correcting ::  Stewart  to NOUN when prev tag is  NOUN
# Correcting ::  Spitler  to NOUN when prev tag is  NOUN
# Correcting ::  18,444  to NUM
# Correcting ::  *T*-95  to NOUN when prev tag is  PRON
# Correcting ::  306  to NUM
# Correcting ::  rang  to NOUN when prev tag is  NOUN
# Correcting ::  313  to NUM
# Correcting ::  Brunswick  to NOUN when prev tag is  NOUN
# Correcting ::  clothing  to NOUN when prev tag is  CONJ
# Correcting ::  expense  to NOUN when prev tag is  NOUN
# Correcting ::  exceeds  to NOUN when prev tag is  NOUN
# Correcting ::  chunk  to NOUN when prev tag is  ADJ
# Correcting ::  consistent  to NOUN when prev tag is  VERB
# Correcting ::  wedded  to NOUN when prev tag is  VERB
# Correcting ::  *T*-213  to NOUN when prev tag is  DET
# Correcting ::  sacrificing  to NOUN when prev tag is  X
# Correcting ::  *T*-140  to NOUN when prev tag is  ADP
# Correcting ::  *T*-173  to NOUN when prev tag is  DET
# Correcting ::  *-104  to NOUN when prev tag is  VERB
# Correcting ::  unfilled  to NOUN when prev tag is  ADP
# Correcting ::  0.5  to NOUN when prev tag is  VERB
# Correcting ::  497.34  to NUM
# Correcting ::  vertically  to NOUN when prev tag is  DET
# Correcting ::  feudal  to NOUN when prev tag is  PRT
# Correcting ::  globally  to NOUN when prev tag is  NOUN
# Correcting ::  brilliantly  to NOUN when prev tag is  ADV
# Correcting ::  comprehensive  to NOUN when prev tag is  ADP
# Correcting ::  reviewing  to NOUN when prev tag is  VERB
# Correcting ::  Mostly  to NOUN when prev tag is  .
# Correcting ::  self-esteem  to NOUN when prev tag is  PRT
# Correcting ::  inauspicious  to NOUN when prev tag is  DET
# Correcting ::  greedy  to NOUN when prev tag is  X
# Correcting ::  manipulators  to NOUN when prev tag is  NOUN
# Correcting ::  shambles  to NOUN when prev tag is  DET
# Correcting ::  free-enterprise  to NOUN when prev tag is  PRT
# Correcting ::  gambling  to NOUN when prev tag is  ADJ
# Correcting ::  den  to NOUN when prev tag is  NOUN
# Correcting ::  odds  to NOUN when prev tag is  DET
# Correcting ::  stacked  to NOUN when prev tag is  ADV
# Correcting ::  550,000  to NUM
# Correcting ::  hunker  to NOUN when prev tag is  PRT
# Correcting ::  47.5  to NUM
# Correcting ::  38.375  to NUM
# Correcting ::  near-record  to NOUN when prev tag is  VERB
# Time Taken with modified Viterbi on Validation Data :: 344.0589439868927
# Accuracy :: 0.9506123268419996
# [[(',', '.'), (('refuses', 'NOUN'), ('refuses', 'VERB'))],
#  [('the', 'DET'), (('wound', 'VERB'), ('wound', 'NOUN'))],
#  [('and', 'CONJ'), (('restructuring', 'NOUN'), ('restructuring', 'VERB'))],
#  [('are', 'VERB'), (('betting', 'NOUN'), ('betting', 'VERB'))],
#  [('health', 'NOUN'), (('care', 'VERB'), ('care', 'NOUN'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('of', 'ADP'), (('pregnant', 'NOUN'), ('pregnant', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('marketing', 'NOUN'), (('push', 'VERB'), ('push', 'NOUN'))],
#  [('push', 'NOUN'), (('stresses', 'NOUN'), ('stresses', 'VERB'))],
#  [('vehicles', 'NOUN'), (('classed', 'NOUN'), ('classed', 'VERB'))],
#  [('carry', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('and', 'CONJ'), (('therefore', 'NOUN'), ('therefore', 'ADV'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'NOUN'), ('touched', 'VERB'))],
#  [("n't", 'ADV'), (('segmenting', 'NOUN'), ('segmenting', 'VERB'))],
#  [('been', 'VERB'), (('spending', 'NOUN'), ('spending', 'VERB'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('The', 'DET'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [("'s", 'PRT'), (('mediocre', 'NOUN'), ('mediocre', 'ADJ'))],
#  [('.', '.'), (('4', 'NUM'), ('4', 'X'))],
#  [('quarterly', 'ADJ'), (('refunding', 'NOUN'), ('refunding', 'VERB'))],
#  [('kids', 'NOUN'), (('broke', 'NOUN'), ('broke', 'VERB'))],
#  [('another', 'DET'), (('drag-down', 'NOUN'), ('drag-down', 'ADJ'))],
#  [('be', 'VERB'), (('real', 'ADJ'), ('real', 'ADV'))],
#  [('a', 'DET'), (('first-rate', 'NOUN'), ('first-rate', 'ADJ'))],
#  [('Parliament', 'NOUN'), (('authorized', 'NOUN'), ('authorized', 'VERB'))],
#  [('funds', 'NOUN'), (('offer', 'NOUN'), ('offer', 'VERB'))],
#  [('travel', 'NOUN'), (('prompts', 'NOUN'), ('prompts', 'VERB'))],
#  [('set', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('bilingual', 'NOUN'), ('bilingual', 'ADJ'))],
#  [('So', 'ADV'), (('Long', 'NOUN'), ('Long', 'ADJ'))],
#  [('*', 'X'), (('prosecuting', 'NOUN'), ('prosecuting', 'VERB'))],
#  [('alternative', 'NOUN'), (('minimum', 'ADJ'), ('minimum', 'NOUN'))],
#  [('from', 'ADP'), (('soured', 'NOUN'), ('soured', 'ADJ'))],
#  [('.', '.'), (('Second', 'NOUN'), ('Second', 'ADJ'))],
#  [('to', 'PRT'), (('unwind', 'NOUN'), ('unwind', 'VERB'))],
#  [('Board', 'NOUN'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('*EXP*-3', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('in', 'PRT'), (('unproductive', 'NOUN'), ('unproductive', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('so', 'ADV'), (('hierarchical', 'NOUN'), ('hierarchical', 'ADJ'))],
#  [('the', 'DET'), (('assistant', 'NOUN'), ('assistant', 'ADJ'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('was', 'VERB'), (('chary', 'NOUN'), ('chary', 'ADJ'))],
#  [('short-term', 'ADJ'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('take', 'VERB'), (('on', 'ADP'), ('on', 'PRT'))],
#  [('riders', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-1', 'X'), (('trespass', 'NOUN'), ('trespass', 'VERB'))],
#  [('Ringers', 'NOUN'), (('memorize', 'NOUN'), ('memorize', 'VERB'))],
#  [('which', 'DET'), (('*T*-224', 'NOUN'), ('*T*-224', 'X'))],
#  [('have', 'VERB'), (('odd-sounding', 'NOUN'), ('odd-sounding', 'ADJ'))],
#  [('a', 'DET'), (('worst-case', 'NOUN'), ('worst-case', 'ADJ'))],
#  [('forced', 'VERB'), (('*-158', 'NOUN'), ('*-158', 'X'))],
#  [('and', 'CONJ'), (('security-type', 'NOUN'), ('security-type', 'ADJ'))],
#  [('training', 'NOUN'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('the', 'DET'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [(',', '.'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('Constitution', 'NOUN'), (('authorizes', 'NOUN'), ('authorizes', 'VERB'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('not', 'ADV'), (('partial', 'NOUN'), ('partial', 'ADJ'))],
#  [('Pan', 'NOUN'), (('Am', 'NOUN'), ('Am', 'VERB'))],
#  [('has', 'VERB'), (('subpoenaed', 'NOUN'), ('subpoenaed', 'VERB'))],
#  [('been', 'VERB'), (('planted', 'NOUN'), ('planted', 'VERB'))],
#  [('*-2', 'X'), (('aboard', 'NOUN'), ('aboard', 'ADP'))],
#  [('jet', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-3', 'X'), (('exploded', 'NOUN'), ('exploded', 'VERB'))],
#  [('of', 'ADP'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('from', 'ADP'), (('unfounded', 'NOUN'), ('unfounded', 'ADJ'))],
#  [('to', 'PRT'), (('highlight', 'NOUN'), ('highlight', 'VERB'))],
#  [('who', 'PRON'), (('*T*-185', 'NOUN'), ('*T*-185', 'X'))],
#  [('No', 'DET'), (('one', 'NUM'), ('one', 'PRON'))],
#  [('the', 'DET'), (('snaking', 'NOUN'), ('snaking', 'VERB'))],
#  [('*-2', 'X'), (('muffled', 'NOUN'), ('muffled', 'VERB'))],
#  [('tried', 'VERB'), (('packaging', 'NOUN'), ('packaging', 'VERB'))],
#  [('packaging', 'VERB'), (('before', 'ADP'), ('before', 'ADV'))],
#  [('what', 'PRON'), (('*T*-170', 'NOUN'), ('*T*-170', 'X'))],
#  [('what', 'PRON'), (('*T*-171', 'NOUN'), ('*T*-171', 'X'))],
#  [('forced', 'VERB'), (('*-100', 'NOUN'), ('*-100', 'X'))],
#  [('*T*-2', 'X'), (('costs', 'NOUN'), ('costs', 'VERB'))],
#  [('a', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('reached', 'VERB'), (('*-120', 'NOUN'), ('*-120', 'X'))],
#  [('have', 'VERB'), (('reaped', 'NOUN'), ('reaped', 'VERB'))],
#  [('their', 'PRON'), (('biannual', 'NOUN'), ('biannual', 'ADJ'))],
#  [('typically', 'ADV'), (('jet', 'NOUN'), ('jet', 'VERB'))],
#  [('the', 'DET'), (('sunny', 'NOUN'), ('sunny', 'ADJ'))],
#  [('and', 'CONJ'), (('Hot', 'ADJ'), ('Hot', 'NOUN'))],
#  [('is', 'VERB'), (('laying', 'NOUN'), ('laying', 'VERB'))],
#  [('average', 'ADJ'), (('8.19', 'NOUN'), ('8.19', 'NUM'))],
#  [('from', 'ADP'), (('8.22', 'NOUN'), ('8.22', 'NUM'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('average', 'ADJ'), (('8.53', 'NOUN'), ('8.53', 'NUM'))],
#  [('from', 'ADP'), (('8.56', 'NOUN'), ('8.56', 'NUM'))],
#  [('He', 'PRON'), (('increases', 'NOUN'), ('increases', 'VERB'))],
#  [('*-87', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('off', 'PRT'), (('drastically', 'NOUN'), ('drastically', 'ADV'))],
#  [('*-1', 'X'), (('defying', 'NOUN'), ('defying', 'VERB'))],
#  [('defying', 'VERB'), (('sweeping', 'VERB'), ('sweeping', 'ADJ'))],
#  [('*-2', 'X'), (('bundling', 'NOUN'), ('bundling', 'VERB'))],
#  [('who', 'PRON'), (('*T*-203', 'NOUN'), ('*T*-203', 'X'))],
#  [('replace', 'VERB'), (('British', 'ADJ'), ('British', 'NOUN'))],
#  [('.', '.'), (('FIRST', 'NOUN'), ('FIRST', 'NUM'))],
#  [('largely', 'ADV'), (('hugging', 'NOUN'), ('hugging', 'VERB'))],
#  [('might', 'VERB'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [('or', 'CONJ'), (('burn', 'NOUN'), ('burn', 'VERB'))],
#  [('burn', 'VERB'), (('cleaner-burning', 'NOUN'), ('cleaner-burning', 'ADJ'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('had', 'VERB'), (('faded', 'NOUN'), ('faded', 'VERB'))],
#  [('the', 'DET'), (('yellow', 'NOUN'), ('yellow', 'ADJ'))],
#  [('were', 'VERB'), (('corrected', 'NOUN'), ('corrected', 'VERB'))],
#  [('not', 'ADV'), (('profit', 'VERB'), ('profit', 'NOUN'))],
#  [('amid', 'ADP'), (('growing', 'ADJ'), ('growing', 'VERB'))],
#  [('issue', 'NOUN'), (('trades', 'NOUN'), ('trades', 'VERB'))],
#  [('its', 'PRON'), (('face', 'VERB'), ('face', 'NOUN'))],
#  [('of', 'ADP'), (('American-made', 'NOUN'), ('American-made', 'ADJ'))],
#  [('times', 'NOUN'), (('lengthen', 'NOUN'), ('lengthen', 'VERB'))],
#  [('``', '.'), (('minority-owned', 'NOUN'), ('minority-owned', 'ADJ'))],
#  [('a', 'DET'), (('blighted', 'NOUN'), ('blighted', 'ADJ'))],
#  [('*', 'X'), (('famous', 'NOUN'), ('famous', 'ADJ'))],
#  [('with', 'ADP'), (('combined', 'ADJ'), ('combined', 'VERB'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('trend', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('accelerated', 'ADJ'), ('accelerated', 'VERB'))],
#  [('a', 'DET'), (('sometimes-tawdry', 'NOUN'), ('sometimes-tawdry', 'ADJ'))],
#  [('$', '.'), (('9.3', 'NOUN'), ('9.3', 'NUM'))],
#  [('to', 'PRT'), (('English-speaking', 'NOUN'), ('English-speaking', 'ADJ'))],
#  [('*-1', 'X'), (('recruiting', 'NOUN'), ('recruiting', 'VERB'))],
#  [('quite', 'ADV'), (('content', 'NOUN'), ('content', 'ADJ'))],
#  [('a', 'DET'), (('lousy', 'NOUN'), ('lousy', 'ADJ'))],
#  [('*T*-1', 'X'), (('anyway', 'NOUN'), ('anyway', 'ADV'))],
#  [('and', 'CONJ'), (('contingency-fee', 'NOUN'), ('contingency-fee', 'ADJ'))],
#  [('cut', 'NOUN'), (('either', 'CONJ'), ('either', 'DET'))],
#  [('.', '.'), (('Preliminary', 'NOUN'), ('Preliminary', 'ADJ'))],
#  [("'s", 'PRT'), (('export-oriented', 'NOUN'), ('export-oriented', 'ADJ'))],
#  [('Its', 'PRON'), (('entrenched', 'NOUN'), ('entrenched', 'VERB'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('push', 'VERB'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('insider', 'NOUN'), (('commercial', 'NOUN'), ('commercial', 'ADJ'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('to', 'PRT'), (('present', 'ADJ'), ('present', 'VERB'))],
#  [('to', 'PRT'), (('appease', 'NOUN'), ('appease', 'VERB'))],
#  [('appease', 'VERB'), (('Midwestern', 'NOUN'), ('Midwestern', 'ADJ'))],
#  [('from', 'ADP'), (('high-polluting', 'NOUN'), ('high-polluting', 'ADJ'))],
#  [('on', 'ADP'), (('cost-sharing', 'ADJ'), ('cost-sharing', 'NOUN'))],
#  [(':', '.'), (('Crude', 'NOUN'), ('Crude', 'ADJ'))],
#  [('but', 'CONJ'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('be', 'VERB'), (('no', 'DET'), ('no', 'ADV'))],
#  [('of', 'ADP'), (('bankrupt', 'NOUN'), ('bankrupt', 'ADJ'))],
#  [('to', 'PRT'), (('form', 'NOUN'), ('form', 'VERB'))],
#  [('complete', 'VERB'), (('most', 'ADV'), ('most', 'ADJ'))],
#  [('a', 'DET'), (('59-year-old', 'NUM'), ('59-year-old', 'ADJ'))],
#  [('see', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('much', 'ADJ'), (('point', 'VERB'), ('point', 'NOUN'))],
#  [('*', 'X'), (('outlawing', 'NOUN'), ('outlawing', 'VERB'))],
#  [('do', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('a', 'DET'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('*-1', 'X'), (('Crude', 'NOUN'), ('Crude', 'ADJ'))],
#  [('triggered', 'VERB'), (('explosive', 'NOUN'), ('explosive', 'ADJ'))],
#  [('Gulf', 'NOUN'), (('rebuffed', 'NOUN'), ('rebuffed', 'VERB'))],
#  [('rebuffed', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('would', 'VERB'), (('study', 'NOUN'), ('study', 'VERB'))],
#  [('.', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [('figures', 'NOUN'), (('contrast', 'NOUN'), ('contrast', 'VERB'))],
#  [('a', 'DET'), (('raise', 'VERB'), ('raise', 'NOUN'))],
#  [('$', '.'), (('1.85', 'NOUN'), ('1.85', 'NUM'))],
#  [('$', '.'), (('1.85', 'NOUN'), ('1.85', 'NUM'))],
#  [('and', 'CONJ'), (('automated', 'NOUN'), ('automated', 'VERB'))],
#  [('trading', 'NOUN'), (('threatens', 'NOUN'), ('threatens', 'VERB'))],
#  [('Board', 'NOUN'),
#   (('stock-specialist', 'NOUN'), ('stock-specialist', 'ADJ'))],
#  [('firms', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-255', 'NOUN'), ('*T*-255', 'X'))],
#  [('-RRB-', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('a', 'DET'), (('Hawaiian', 'NOUN'), ('Hawaiian', 'ADJ'))],
#  [('squeezed', 'VERB'), (('*-122', 'NOUN'), ('*-122', 'X'))],
#  [('the', 'DET'), (('mid-1970s', 'NOUN'), ('mid-1970s', 'NUM'))],
#  [('who', 'PRON'), (('*T*-130', 'NOUN'), ('*T*-130', 'X'))],
#  [('who', 'PRON'), (('*T*-131', 'NOUN'), ('*T*-131', 'X'))],
#  [('about', 'ADP'), (('jurisdictional', 'NOUN'), ('jurisdictional', 'ADJ'))],
#  [('which', 'DET'), (('*T*-217', 'NOUN'), ('*T*-217', 'X'))],
#  [('*T*-217', 'X'), (('uses', 'NOUN'), ('uses', 'VERB'))],
#  [('trend', 'NOUN'), (('improves', 'NOUN'), ('improves', 'VERB'))],
#  [('.', '.'), (('Unfortunately', 'NOUN'), ('Unfortunately', 'ADV'))],
#  [('London', 'NOUN'), (('serves', 'NOUN'), ('serves', 'VERB'))],
#  [('unit', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-108', 'NOUN'), ('*T*-108', 'X'))],
#  [('which', 'DET'), (('*T*-109', 'NOUN'), ('*T*-109', 'X'))],
#  [('*T*-109', 'X'), (('later', 'ADJ'), ('later', 'ADV'))],
#  [('Treasury', 'NOUN'), (('estimates', 'NOUN'), ('estimates', 'VERB'))],
#  [('it', 'PRON'), (('decides', 'NOUN'), ('decides', 'VERB'))],
#  [('to', 'PRT'), (('aim', 'NOUN'), ('aim', 'VERB'))],
#  [('Greenville', 'NOUN'), (('senior', 'ADJ'), ('senior', 'NOUN'))],
#  [('will', 'VERB'), (('sweeten', 'NOUN'), ('sweeten', 'VERB'))],
#  [('``', '.'), (('Invariably', 'NOUN'), ('Invariably', 'ADV'))],
#  [('*', 'X'), (('tapping', 'NOUN'), ('tapping', 'VERB'))],
#  [('IRS', 'NOUN'), (('rarely', 'NOUN'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', 'NOUN'), ('acted', 'VERB'))],
#  [('and', 'CONJ'), (('share', 'NOUN'), ('share', 'VERB'))],
#  [('compassion', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('offer', 'NOUN'), ('offer', 'VERB'))],
#  [('of', 'ADP'), (('Solomonic', 'NOUN'), ('Solomonic', 'ADJ'))],
#  [('.', '.'), (('Financially', 'NOUN'), ('Financially', 'ADV'))],
#  [('who', 'PRON'), (('*T*-91', 'NOUN'), ('*T*-91', 'X'))],
#  [('.', '.'), (('Defending', 'NOUN'), ('Defending', 'VERB'))],
#  [(',', '.'), (('stock-picking', 'NOUN'), ('stock-picking', 'ADJ'))],
#  [('the', 'DET'), (('clannish', 'NOUN'), ('clannish', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-95', 'NOUN'), ('*T*-95', 'X'))],
#  [(',', '.'), (('net', 'ADJ'), ('net', 'NOUN'))],
#  [('Younkers', 'NOUN'), (('rang', 'NOUN'), ('rang', 'VERB'))],
#  [('declined', 'VERB'), (('comment', 'VERB'), ('comment', 'NOUN'))],
#  [('expense', 'NOUN'), (('exceeds', 'NOUN'), ('exceeds', 'VERB'))],
#  [('produce', 'VERB'), (('consistent', 'NOUN'), ('consistent', 'ADJ'))],
#  [('has', 'VERB'), (('wedded', 'NOUN'), ('wedded', 'VERB'))],
#  [('which', 'DET'), (('*T*-213', 'NOUN'), ('*T*-213', 'X'))],
#  [('*-2', 'X'), (('sacrificing', 'NOUN'), ('sacrificing', 'VERB'))],
#  [('sale', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-140', 'NOUN'), ('*T*-140', 'X'))],
#  [('which', 'DET'), (('*T*-173', 'NOUN'), ('*T*-173', 'X'))],
#  [('exercised', 'VERB'), (('*-104', 'NOUN'), ('*-104', 'X'))],
#  [('of', 'ADP'), (('unfilled', 'NOUN'), ('unfilled', 'ADJ'))],
#  [('rose', 'VERB'), (('0.5', 'NOUN'), ('0.5', 'NUM'))],
#  [('These', 'DET'), (('vertically', 'NOUN'), ('vertically', 'ADV'))],
#  [('integrated', 'VERB'), (('combines', 'VERB'), ('combines', 'NOUN'))],
#  [('their', 'PRON'), (('start', 'VERB'), ('start', 'NOUN'))],
#  [("'s", 'PRT'), (('feudal', 'NOUN'), ('feudal', 'ADJ'))],
#  [(',', '.'), (('deal', 'NOUN'), ('deal', 'VERB'))],
#  [('deal', 'VERB'), (('globally', 'NOUN'), ('globally', 'ADV'))],
#  [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('quite', 'ADV'), (('brilliantly', 'NOUN'), ('brilliantly', 'ADV'))],
#  [('*EXP*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('something', 'NOUN'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('that', 'ADV'), (('comprehensive', 'NOUN'), ('comprehensive', 'ADJ'))],
#  [('are', 'VERB'), (('reviewing', 'NOUN'), ('reviewing', 'VERB'))],
#  [('The', 'DET'),
#   (('financial-services', 'ADJ'), ('financial-services', 'NOUN'))],
#  [('.', '.'), (('Mostly', 'NOUN'), ('Mostly', 'ADV'))],
#  [('an', 'DET'), (('inauspicious', 'NOUN'), ('inauspicious', 'ADJ'))],
#  [('inauspicious', 'ADJ'), (('beginning', 'VERB'), ('beginning', 'NOUN'))],
#  [('0', 'X'), (('greedy', 'NOUN'), ('greedy', 'ADJ'))],
#  [('heavily', 'ADV'), (('stacked', 'NOUN'), ('stacked', 'VERB'))],
#  [('The', 'DET'), (('record', 'NOUN'), ('record', 'ADJ'))],
#  [('to', 'PRT'), (('hunker', 'NOUN'), ('hunker', 'VERB'))],
#  [('to', 'PRT'), (('end', 'NOUN'), ('end', 'VERB'))],
#  [('achieve', 'VERB'), (('near-record', 'NOUN'), ('near-record', 'ADJ'))]]

# %%
# Read the Test Sentences 
test_file = pd.read_csv('Test_sentences.txt', sep="\t", header = None)
test_sent_list = test_file[0].tolist()
test_run = []
for sent in test_sent_list:
    test_run.append(nltk.pos_tag(nltk.word_tokenize(sent), 'universal'))  
test_run_base = [tup for sent in test_run for tup in sent]
test_tagged_words = [tup[0] for tup in test_run_base]
test_tagged_words
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %%
# tagging the test sentences
start = time.time()
tagged_seq = Viterbi(test_tagged_words)
end = time.time()
difference = end-start
print ("Time Taken with Vanila Viterbi on Test Data ::", difference)

# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
accuracy_vanila = len(check)/len(tagged_seq)
print ("Accuracy ::", accuracy_vanila)
incorrect_tagged_cases_vanila = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases_vanila
# Out:
# Time Taken with Vanila Viterbi on Test Data :: 14.898024797439575
# Accuracy :: 0.7569060773480663
# [[('.', '.'), (('Android', '.'), ('Android', 'NOUN'))],
#  [('by', 'ADP'), (('Google', '.'), ('Google', 'NOUN'))],
#  [('.', '.'), (('Android', '.'), ('Android', 'NOUN'))],
#  [('best-selling', 'ADJ'), (('OS', '.'), ('OS', 'NOUN'))],
#  [('OS', 'NOUN'), (('worldwide', '.'), ('worldwide', 'NOUN'))],
#  [('on', 'ADP'), (('smartphones', '.'), ('smartphones', 'NOUN'))],
#  [('since', 'ADP'), (('2011', '.'), ('2011', 'NUM'))],
#  [('since', 'ADP'), (('2013', '.'), ('2013', 'NUM'))],
#  [('.', '.'), (('Google', '.'), ('Google', 'NOUN'))],
#  [('and', 'CONJ'), (('Twitter', '.'), ('Twitter', 'NOUN'))],
#  [('in', 'ADP'), (('2015', '.'), ('2015', 'NUM'))],
#  [('gave', 'VERB'), (('Google', '.'), ('Google', 'NOUN'))],
#  [('to', 'PRT'), (('Twitter', '.'), ('Twitter', 'NOUN'))],
#  [('Twitter', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [("'s", 'PRT'), (('firehose', '.'), ('firehose', 'NOUN'))],
#  [('.', '.'), (('Twitter', '.'), ('Twitter', 'NOUN'))],
#  [('an', 'DET'), (('online', '.'), ('online', 'ADJ'))],
#  [('and', 'CONJ'), (('interact', '.'), ('interact', 'NOUN'))],
#  [('with', 'ADP'), (('messages', '.'), ('messages', 'NOUN'))],
#  [('as', 'ADP'), (('tweets', '.'), ('tweets', 'NOUN'))],
#  [('a', 'DET'), (('domineering', '.'), ('domineering', 'ADJ'))],
#  [('television', 'NOUN'), (('personality', '.'), ('personality', 'NOUN'))],
#  [('The', 'DET'), (('2018', '.'), ('2018', 'NUM'))],
#  [('2018', 'NUM'), (('FIFA', '.'), ('FIFA', 'NOUN'))],
#  [('World', 'NOUN'), (('Cup', '.'), ('Cup', 'NOUN'))],
#  [('the', 'DET'), (('21st', '.'), ('21st', 'NUM'))],
#  [('21st', 'NUM'), (('FIFA', '.'), ('FIFA', 'NOUN'))],
#  [('World', 'NOUN'), (('Cup', '.'), ('Cup', 'NOUN'))],
#  [('football', 'NOUN'), (('tournament', '.'), ('tournament', 'NOUN'))],
#  [('tournament', 'NOUN'), (('contested', '.'), ('contested', 'VERB'))],
#  [('World', 'NOUN'), (('Cup', '.'), ('Cup', 'NOUN'))],
#  [('the', 'DET'), (('11th', 'ADJ'), ('11th', 'NUM'))],
#  [('.', '.'), (('Show', 'NOUN'), ('Show', 'VERB'))],
#  [('round', 'NOUN'), (('trips', '.'), ('trips', 'NOUN'))],
#  [('to', 'PRT'), (('Atlanta', 'NOUN'), ('Atlanta', 'VERB'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('.', '.'), (('Show', 'NOUN'), ('Show', 'VERB'))],
#  [('at', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('and', 'CONJ'), (('arriving', '.'), ('arriving', 'NOUN'))],
#  [('.', '.'), (('NASA', '.'), ('NASA', 'NOUN'))],
#  [('NASA', 'NOUN'), (('invited', '.'), ('invited', 'VERB'))],
#  [('to', 'PRT'), (('experience', 'NOUN'), ('experience', 'VERB'))],
#  [('of', 'ADP'), (('ICESAT-2', '.'), ('ICESAT-2', 'NOUN'))],
#  [('ICESAT-2', 'NOUN'), (('Satellite', '.'), ('Satellite', 'NOUN'))]]

# %%
# tagging the test sentences using modified Viterbi
start = time.time()
tagged_seq = ViterbiNew(test_tagged_words)
end = time.time()
difference = end-start
print ("Time Taken with Modified Viterbi on Test Data ::", difference)

# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
accuracy_new = len(check)/len(tagged_seq)
print ("Accuracy ::", accuracy_new)
incorrect_tagged_cases_new = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases_new
# Out:
# Correcting ::  Android  with most common tag  NOUN
# Correcting ::  Google  to NOUN when prev tag is  ADP
# Correcting ::  Android  to NOUN when prev tag is  .
# Correcting ::  OS  to NOUN when prev tag is  ADJ
# Correcting ::  worldwide  to NOUN when prev tag is  NOUN
# Correcting ::  smartphones  to NOUN when prev tag is  ADP
# Correcting ::  2011  to NUM
# Correcting ::  2013  to NUM
# Correcting ::  Google  to NOUN when prev tag is  .
# Correcting ::  Twitter  to NOUN when prev tag is  CONJ
# Correcting ::  2015  to NUM
# Correcting ::  Google  to NOUN when prev tag is  VERB
# Correcting ::  Twitter  to NOUN when prev tag is  PRT
# Correcting ::  firehose  to NOUN when prev tag is  PRT
# Correcting ::  Twitter  to NOUN when prev tag is  .
# Correcting ::  online  to NOUN when prev tag is  DET
# Correcting ::  interact  to NOUN when prev tag is  CONJ
# Correcting ::  messages  to NOUN when prev tag is  ADP
# Correcting ::  tweets  to NOUN when prev tag is  ADP
# Correcting ::  domineering  to NOUN when prev tag is  DET
# Correcting ::  personality  to NOUN when prev tag is  NOUN
# Correcting ::  2018  to NUM
# Correcting ::  FIFA  to NOUN when prev tag is  NUM
# Correcting ::  Cup  to NOUN when prev tag is  NOUN
# Correcting ::  21st  to NUM
# Correcting ::  FIFA  to NOUN when prev tag is  NUM
# Correcting ::  Cup  to NOUN when prev tag is  NOUN
# Correcting ::  tournament  to NOUN when prev tag is  NOUN
# Correcting ::  contested  to NOUN when prev tag is  NOUN
# Correcting ::  Cup  to NOUN when prev tag is  NOUN
# Correcting ::  trips  to NOUN when prev tag is  NOUN
# Correcting ::  arriving  to NOUN when prev tag is  CONJ
# Correcting ::  NASA  to NOUN when prev tag is  .
# Correcting ::  invited  to NOUN when prev tag is  NOUN
# Correcting ::  ICESAT-2  to NOUN when prev tag is  ADP
# Correcting ::  Satellite  to NOUN when prev tag is  NOUN
# Time Taken with Modified Viterbi on Test Data :: 19.87427020072937
# Accuracy :: 0.9337016574585635
# [[('2015', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('an', 'DET'), (('online', 'NOUN'), ('online', 'ADJ'))],
#  [('a', 'DET'), (('domineering', 'NOUN'), ('domineering', 'ADJ'))],
#  [('tournament', 'NOUN'), (('contested', 'NOUN'), ('contested', 'VERB'))],
#  [('the', 'DET'), (('11th', 'ADJ'), ('11th', 'NUM'))],
#  [('.', '.'), (('Show', 'NOUN'), ('Show', 'VERB'))],
#  [('to', 'PRT'), (('Atlanta', 'NOUN'), ('Atlanta', 'VERB'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('.', '.'), (('Show', 'NOUN'), ('Show', 'VERB'))],
#  [('at', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('NASA', 'NOUN'), (('invited', 'NOUN'), ('invited', 'VERB'))],
#  [('to', 'PRT'), (('experience', 'NOUN'), ('experience', 'VERB'))]]

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
# Improvement in acuracy over vanilla Viterbi Algorith
accuracy_improvement = round(((accuracy_new - accuracy_vanila)/accuracy_vanila)*100, 2)
print ("Accuracy Improvement = ", accuracy_improvement, "%")
# Out:
# Accuracy Improvement =  23.36 %

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# List down at least three cases from the sample test file 
# (i.e. unknown word-tag pairs) which were incorrectly tagged 
# by the original Viterbi POS tagger and got corrected after your modifications.

# Case 1
# Numbers
# Correcting ::  2011  to NUM
# Correcting ::  2013  to NUM
# checkNumberTagger has correctly tagged these as NUM


# Case 2
# Prev Tag
# Correcting ::  Google  to NOUN when prev tag is  VERB
# Correcting ::  Twitter  to NOUN when prev tag is  PRT
# checkBiagramTagger has used prev tag frequeny to tag the correct word

# Case 3
# Most Frequent Tag 
# Correcting ::  Android  with most common tag  NOUN
# checkLexicanTagger has used most frequent tag instead of random tag
