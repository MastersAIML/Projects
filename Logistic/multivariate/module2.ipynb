# %%
# Importing Pandas and NumPy
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("pima_indian_diabetes.csv")
df.head()
# Out:
#    No_Times_Pregnant  Plasma_Glucose  Diastolic_BP  Triceps  Insulin   BMI  \
# 0                  1              89            66       23       94  28.1
# 1                  0             137            40       35      168  43.1
# 2                  3              78            50       32       88  31.0
# 3                  2             197            70       45      543  30.5
# 4                  1             189            60       23      846  30.1
#
#    Age  Diabetes
# 0   21         0
# 1   33         1
# 2   26         1
# 3   53         1
# 4   59         1

# %%
normalized_df=df[['No_Times_Pregnant','Plasma_Glucose','Diastolic_BP','Triceps','Insulin','BMI','Age']]
normalized_df=(normalized_df-normalized_df.mean())/(normalized_df.std())
normalized_df
# Out:
#      No_Times_Pregnant  Plasma_Glucose  Diastolic_BP   Triceps   Insulin  \
# 0            -0.716511       -1.089653     -0.373178 -0.584363 -0.522175
# 1            -1.027899        0.465719     -2.453828  0.556709  0.100502
# 2            -0.093734       -1.446093     -1.653578  0.271441 -0.572662
# 3            -0.405123        2.409934     -0.053078  1.507603  3.255961
# 4            -0.716511        2.150705     -0.853328 -0.584363  5.805571
# 5             0.529042        1.405423      0.106972 -0.964720  0.159404
# 6            -1.027899       -0.149949      1.067272  1.697782  0.622205
# 7            -0.716511       -0.636003     -3.254079  0.841977 -0.614735
# 8            -0.716511       -0.247160     -0.053078  0.081263 -0.505346
# 9            -0.093734        0.109279      1.387373  1.127246  0.664278
# 10            2.397372        0.660140      1.867523  0.366531 -0.084618
# 11            2.085984        0.076876     -0.053078 -0.299095 -0.345469
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# Putting feature variable to X
X = normalized_df

# Putting response variable to y
y = df['Diabetes']

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=100)

# %%
import statsmodels.api as sm

# %%
# Logistic regression model
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               Diabetes   No. Observations:                  274
# Model:                            GLM   Df Residuals:                      266
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -122.11
# Date:                Fri, 22 Jun 2018   Deviance:                       244.22
# Time:                        14:51:13   Pearson chi2:                     264.
# No. Iterations:                     5   Covariance Type:             nonrobust
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn.feature_selection import RFE
rfe = RFE(logreg, 5)             # running RFE with 13 variables as output
rfe = rfe.fit(X,y)
print(rfe.support_)           # Printing the boolean results
print(rfe.ranking_)           # Printing the ranking
# Out:
# [ True  True False  True False  True  True]
# [1 1 3 1 2 1 1]
