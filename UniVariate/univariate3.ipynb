# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("EDA_census_csv.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3132 entries, 0 to 3131
# Data columns (total 15 columns):
# table_name            3132 non-null object
# state_code            3132 non-null int64
# dist_code             3132 non-null int64
# area_name             3132 non-null object
# total_rural_urban     3132 non-null object
# age_group             3132 non-null object
# total_persons         3132 non-null int64
# total_males           3132 non-null int64
# total_females         3132 non-null int64
# illiterate_persons    3132 non-null int64
# illiterate_males      3132 non-null int64
# illiterate_females    3132 non-null int64
# literate_persons      3132 non-null int64
# literate_males        3132 non-null int64
# literate_females      3132 non-null int64
# dtypes: int64(11), object(4)
# memory usage: 367.1+ KB
#   table_name  state_code  dist_code area_name total_rural_urban age_group  \
# 0      C2308           0          0     INDIA             Total  All ages
# ...

# %%
df['lit_percentage'] = (df.literate_persons/df.total_persons)*100
df1 = df[['age_group','lit_percentage']]
print(df1)
# Out:
#            age_group  lit_percentage
# 0           All ages       63.066084
# 1                0-6        0.000000
# 2                  7       72.818658
# 3                  8       84.680522
# 4                  9       89.362038
# 5                 10       88.693071
# 6                 11       91.962826
# 7                 12       91.421234
# 8                 13       92.543554
# 9                 14       91.682750
# 10                15       89.961344
# 11                16       89.783437
# 12                17       90.392562
# 13                18       86.665872
# 14                19       87.637647
# 15             20-24       83.235699
# 16             25-29       77.681141
# 17             30-34       72.538435
# 18             35-39       67.274016
# 19             40-44       62.993414
# 20             45-49       59.758607
# 21             50-54       57.565672
# 22             55-59       54.830491
# 23             60-64       46.926523
# ...

# %%
df['fem_lit_percentage'] = (df.literate_females/df.literate_persons)*100
df2 = df.loc[df['age_group'] == 'All ages']
df3 = df2.loc[df['total_rural_urban'] == 'Total'].sort_values(['fem_lit_percentage'], ascending=False)
#df.groupby(df['area_name'])['Maths..'].mean()
df3.head()
# Out:
#      table_name  state_code  dist_code           area_name total_rural_urban  \
# 2784      C2308          32          0      State - KERALA             Total
# 1479      C2308          17          0   State - MEGHALAYA             Total
# 1305      C2308          15          0     State - MIZORAM             Total
# 2958      C2308          34          0  State - PUDUCHERRY             Total
# 2610      C2308          30          0         State - GOA             Total
#
#      age_group  total_persons  total_males  total_females  illiterate_persons  \
# 2784  All ages       33406061     16027412       17378649             5270237
# 1479  All ages        2966889      1491832        1475057             1181884
# 1305  All ages        1097206       555339         541867              249031
# 2958  All ages        1247953       612511         635442              290644
# 2610  All ages        1458545       739140         719405              293058
#
# ...

# %%
df2 = df.loc[df['age_group'] == 'All ages']
df3 = df2.loc[df['total_rural_urban'] == 'Total'].sort_values(['lit_percentage'], ascending=True)
#df.groupby(df['area_name'])['Maths..'].mean()
df3.head()
# Out:
#      table_name  state_code  dist_code                  area_name  \
# 870       C2308          10          0              State - BIHAR
# 1044      C2308          12          0  State - ARUNACHAL PRADESH
# 1740      C2308          20          0          State - JHARKHAND
# 696       C2308           8          0          State - RAJASTHAN
# 87        C2308           1          0    State - JAMMU & KASHMIR
#
#      total_rural_urban age_group  total_persons  total_males  total_females  \
# 870              Total  All ages      104099452     54278157       49821295
# 1044             Total  All ages        1383727       713912         669815
# 1740             Total  All ages       32988134     16930315       16057819
# 696              Total  All ages       68548437     35550997       32997440
# 87               Total  All ages       12541302      6640662        5900640
#
#       illiterate_persons  illiterate_males  illiterate_females  \
# ...
