# %%
import pymysql
import csv
from datetime import datetime
import re

# create a connection object 'conn'
conn = pymysql.connect(host="localhost", # your host, localhost for your local machine
                     user="wodbuser", # your username, usually "root" for localhost
                      passwd="wodbpassword", # your password
                      db="wodb", connect_timeout=5) # name of the data base; world comes inbuilt with mysql

# %%
# field names
# ['Order ID', 'Order-status', 'Brand', 'Kitchen', 
# 'Order-relay-time(ordered time)', 'Order-acceptance-time <placed_time>', 
# 'Order-delivery-time', 'Total-bill-amount <bill>', 'Tax Restaurant', 'Item-SGST', 
# 'Item-CGST', 'Item-IGST', 'PackagingCharge-SGST', 'PackagingCharge-CGST', 'PackagingCharge-IGST', 
# 'ServiceCharge-SGST', 'ServiceCharge-CGST', 'ServiceCharge-IGST', 'Item-GST-Inclusive', 
# 'Packaging_GST_Inclusive', 'ServiceCharge-GST-inclusive', 'Restaurant Discount', 'Packing-charge', 
# 'Cancelled reason', 'Food-prepared <Yes/No>', 'Order-Cancellation-time', 'Edited-status', 'Item-count', 
# 'MOU type', 'Cancellation-responsible-entity', 'Restaurant-bear', 
# 'Item1-name_reward_type_quantity_price+Variants+Addons', '', '', '', '']
# Tables - 
# AggOrder
# orderId status('Order-status') billNumber('Order ID') slot kitchen('Kitchen') paymentMode source('Swiggy') brand('Brand') 
# orderComment orderStartTime ('Order-relay-time(ordered time)')
# orderEndTime('Order-delivery-time') subtotal total('Total-bill-amount <bill>') createdAt updatedAt taxExempted
# AggOrderItems
# orderItemId orderId itemName('name') itemPrice('price') itemTotalPrice('price') itemQuantity('quantity') itemType totalDiscount totalTax
# woProductId woProductSkuId createdAt updatedAt
# AggOrderCustomer
# orderCustomerId orderId address1 userId city countryCode country fullName mobile createdAt updatedAt

def getItemmap(itemstring):
    # e.g. - Red Velvet In A Jar_NA_1_12,Punchy Pineapple Cake in Jar_NA_1_12
    itemmap = {}
    if (itemstring == ''):
        return itemmap
    addons = itemstring.split('++')
    itemstring1 = ''
    if (len(addons) == 0):
        return itemmap
    itemstring1 = addons[0]
    variants = itemstring1.split('+')  
    itemstring2 = variants[0]     
    itemtokens = itemstring2.split('_')
    
    if (len(itemtokens) == 4):
        itemmap['name'] = itemtokens[0].strip()
        itemmap['reward_type'] = itemtokens[1].strip()
        itemmap['quantity'] = itemtokens[2].strip()
        itemmap['price'] = itemtokens[3].strip()
    return itemmap
def insertSwiggyOrderItem(cur, orderid, billno, itemstrings):
    # print (itemstrings)
    items = list(map(lambda x: getItemmap(x), itemstrings))
    for item in items:
        if (len(item) == 4):
            sql = "".join(["insert into AggOrderItems (orderId, billNumber, itemName, itemPrice, itemQuantity, createdAt, updatedAt) values('", orderid ,"','", billno, "','", item['name'], "','", item['price'], "','", item['quantity'],"', current_timestamp(), current_timestamp())"])
            cur.execute(sql)
def insertSwiggyOrder(header, row, conn):
    #print ('\n')
    #print (row)
    itemindex = header.index("Item1-name_reward_type_quantity_price+Variants+Addons")
    maxindex = len(header) - 1
    colmap = {'orderId':'S' + row[header.index('Order ID')], 'billNumber':row[header.index('Order ID')], 'status':row[header.index('Order-status')],'kitchen':row[header.index('Kitchen')], 'source':'Swiggy', 'brand':row[header.index('Brand')], 'orderStartTime':row[header.index('Order-relay-time(ordered time)')], 'orderEndTime':row[header.index('Order-delivery-time')], 'total':row[header.index('Total-bill-amount <bill>')]} 
    print (colmap)
    with conn.cursor() as cur:
        tempdatestart = colmap['orderStartTime']
        tempdateend = colmap['orderEndTime']
        datestart = datetime.strptime(tempdatestart,  '%d/%m/%y %H:%M')
        dateend = datetime.strptime(tempdateend,  '%d/%m/%y %H:%M')
        sql = "".join(["insert into AggOrder (orderId, billNumber, status, kitchen, source, brand, orderStartTime, orderEndTime, total, createdAt, updatedAt) values('", colmap['orderId'], "','" , colmap['billNumber'], "','", colmap['status'], "','",colmap['kitchen'],"','",colmap['source'],"','",colmap['brand'],"','", dateend,"','",dateend,"','",colmap['total'],"', current_timestamp(), current_timestamp())"])
        #print (sql)
        cur.execute(sql)
        insertSwiggyOrderItem(cur, colmap['orderId'],colmap['billNumber'], row[itemindex:maxindex])
    conn.commit()
def insertZomatoOrder(header, row, conn):
    print ('\n')
    # print (header)
    orderidindex = -1
    try:
        orderidindex = header.index('Order ID')
    except:
        try:
            orderidindex = header.index('\ufeffOrder Id')
        except:
            orderidindex = -1
    if (orderidindex == -1):
        return
    
    # print (orderidindex)
    colmap = {'orderId':'Z' + row[orderidindex], 'billNumber':row[orderidindex], 'status':row[header.index('Delivery Status')],'kitchen':row[header.index('Kitchen')], 'source':'Zomato', 'brand':row[header.index('Brand')], 'orderStartTime':row[header.index('Order Date')], 'orderEndTime':row[header.index('Order Date')], 'total':row[header.index('Amount')]} 
    with conn.cursor() as cur:
        date = datetime.strptime(colmap['orderStartTime'],  '%I:%M %p, %B %d %Y')
        date = date.strftime('%Y-%m-%d %H:%M:%S')
        sql = "".join(["insert into AggOrder (orderId, billNumber, status, kitchen, source, brand, orderStartTime, orderEndTime, total, createdAt, updatedAt) values('", colmap['orderId'], "','" , colmap['billNumber'], "','", colmap['status'], "','",colmap['kitchen'],"','",colmap['source'],"','",colmap['brand'],"','", date,"','",date,"','",colmap['total'],"', current_timestamp(), current_timestamp())"])
        print (sql)
        cur.execute(sql)
        #insertSwiggyOrderItem(cur, colmap['orderId'],colmap['billNumber'], row[itemindex:maxindex])
    conn.commit()
def insertFoodpandaOrderItem(cur, orderid, billno, itemstrings):
    # print (itemstrings)
    items = itemstrings.split(';')
    for item in items:
        if (len(item) > 1):
            itemqtytemp = re.findall('^\d', item)
            itemqty = itemqtytemp[0]
            itemnametemp = re.findall('\d\s(.*)', item)
            itemname = itemnametemp[0]
            sql = "".join(["insert into AggOrderItems (orderId, billNumber, itemName, itemPrice, itemQuantity, createdAt, updatedAt) values('", orderid ,"','", billno, "','", itemname, "',0,'", itemqty,"', current_timestamp(), current_timestamp())"])
            #print (sql)
            cur.execute(sql)
def insertFoodpandaOrder(header, row, conn):
    print ('\n')
    print (header)
    # ['\ufeffORDER CODE', 'RESTAURANT CODE', 'RESTAURANT NAME', 'FOOD COST', 'CONTAINER PRICE', 'RESTAURANT DELIVERY FEE', 'RESTAURANT SERVICE FEE', 'RIDER PAYS', 'PAYMENT TYPE', 'ITEMS', 'ORDER ITEMS', 'EXPECTED DELIVERY DATE', 'EXPECTED DELIVERY TIME', 'EXPEDITION TYPE', 'STATUS', 'CANCELLATION REASON']
    orderidindex = -1
    try:
        orderidindex = header.index('ORDER CODE')
    except:
        try:
            orderidindex = header.index('\ufeffORDER CODE')
        except:
            orderidindex = -1
    if (orderidindex == -1):
        return
    # WarmOven ( BTM 2nd Stage )
    restname = row[header.index('RESTAURANT NAME')]
    brand = re.findall('^[^\s\(]*', restname)
    kitchen = re.findall('\(\s(.+)\s\)', restname)
    #print (brand[0])
    #print (kitchen[0])
    tempdate = row[header.index('EXPECTED DELIVERY DATE')] + row[header.index('EXPECTED DELIVERY TIME')]
    date = datetime.strptime(tempdate,  '%d/%m/%y%H:%M %p')
    date = date.strftime('%Y-%m-%d %H:%M:%S')
    # 19/09/18
    # 5:15 PM
    # print (orderidindex)
    colmap = {'orderId':'F' + row[orderidindex], 'billNumber':row[orderidindex], 'status':row[header.index('STATUS')],'kitchen':kitchen[0], 'source':'Foodpanda', 'brand':brand[0], 'total':row[header.index('FOOD COST')], 'orderItems':row[header.index('ORDER ITEMS')]} 
    with conn.cursor() as cur:
        sql = "".join(["insert into AggOrder (orderId, billNumber, status, kitchen, source, brand, orderStartTime, orderEndTime, total, createdAt, updatedAt) values('", colmap['orderId'], "','" , colmap['billNumber'], "','", colmap['status'], "','",colmap['kitchen'],"','",colmap['source'],"','",colmap['brand'],"','", date,"','",date,"','",colmap['total'],"', current_timestamp(), current_timestamp())"])
        # print (sql)
        cur.execute(sql)
        # ORDER ITEMS
        insertFoodpandaOrderItem(cur, colmap['orderId'],colmap['billNumber'], colmap['orderItems'])
    conn.commit()

# %%
import xlrd
import csv

messages = []

book = xlrd.open_workbook('Order Wise Item Sales Datab5c07d67-a7da-477b-b6e2-ac0561888588.xlsx', on_demand = True)
first_sheet = book.sheet_by_index(0)
header = first_sheet.row_values(19)
rows = first_sheet.nrows
columns = len(header)
print (header)
print (rows)
i = 20
prevrow = header
while i < rows:
    row = first_sheet.row_values(i)
    if (row[0] == ''):
        j = 0
        while (j < columns):
            if (row[j] == ''):
                row[j] = prevrow[j]
            j = j + 1
    else:
        prevrow = row
    i = i + 1
    print (row)
    insertOrder(header, row, conn)
    
with open('Swiggy_14th.csv') as csvfile:
    reader = csv.reader(csvfile)
    i = 0
    header = []
    for row in reader:
        i+=1
        # print (row)
        if (i == 1):
            header = row
        #else:
            #insertSwiggyOrder(header, row, conn)
with open('Zomato_14th.csv') as csvfile:
    reader = csv.reader(csvfile)
    i = 0
    header = []
    for row in reader:
        i+=1
        if (i == 1):
            header = row
        #else:
            #insertZomatoOrder(header, row, conn)
with open('Foodpanda_14th.csv') as csvfile:
    reader = csv.reader(csvfile)
    i = 0
    header = []
    for row in reader:
        i+=1
        if (i == 1):
            header = row
        #else:
            #insertFoodpandaOrder(header, row, conn)
# Out:
# ['Date', 'Time', 'Bill Number', 'Reference Number', 'Outlet Name', 'Order Status', 'Subtotal', 'Item Name', 'Item Quantity', 'Item Total', 'Item Complementary', 'Item Complementary Quantity', 'Item Discount', 'Item Taxes', 'Item Charges']
# 944
# ['2018-11-11', '12:06 AM', '', '1123563936', 'Warm Oven - Whitefield', 'DELIVERED', 559.0, 'Death by Chocolate Cake [500 gram]', 1.0, 559.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:06 AM', '', '1036831737', 'Slurpy Shakes - Hebbal', 'DELIVERED', 298.0, 'Kit Kat Shake [250 ml]', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:06 AM', '', '1036831737', 'Slurpy Shakes - Hebbal', 'DELIVERED', 298.0, 'Red Velvet Shake [250 ml]', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:08 AM', '', '1048982263', 'Warm Oven - Whitefield', 'DELIVERED', 429.0, 'Black Forest Cake [500 gram]', 1.0, 429.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:13 AM', '', '1666829126', 'Cupcake Bliss - Whitefield', 'DELIVERED', 109.0, 'Red Velvet Cup Cake [Pack of 2]', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:14 AM', '', '1522408488', 'Cupcake Bliss - Whitefield', 'DELIVERED', 99.0, 'Chocolate Cup Cake [Pack of 2]', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:14 AM', '', '1075851165', 'Slurpy Shakes - Hebbal', 'DELIVERED', 149.0, 'Kit Kat Shake [250 ml]', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:26 AM', '', '1083034874', 'Indiana Burgers - Hebbal', 'DELIVERED', 208.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:26 AM', '', '1083034874', 'Indiana Burgers - Hebbal', 'DELIVERED', 208.0, 'Rose Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:28 AM', '', '1568931769', 'Cupcake Bliss - Whitefield', 'DELIVERED', 119.0, 'Kitkat Cup Cake [Pack of 2]', 1.0, 119.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1328910407', 'Indiana Burgers - Hebbal', 'DELIVERED', 414.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1328910407', 'Indiana Burgers - Hebbal', 'DELIVERED', 414.0, 'Veg Mayonnaise [50 grams]', 3.0, 117.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1328910407', 'Indiana Burgers - Hebbal', 'DELIVERED', 414.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1328910407', 'Indiana Burgers - Hebbal', 'DELIVERED', 414.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1191232655', 'Indiana Burgers - Hebbal', 'DELIVERED', 494.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1191232655', 'Indiana Burgers - Hebbal', 'DELIVERED', 494.0, 'Cheese', 2.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1191232655', 'Indiana Burgers - Hebbal', 'DELIVERED', 494.0, 'Veg Mayonnaise [50 grams]', 1.0, 39.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1191232655', 'Indiana Burgers - Hebbal', 'DELIVERED', 494.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1191232655', 'Indiana Burgers - Hebbal', 'DELIVERED', 494.0, 'Egg Mayonnaise [50 grams]', 2.0, 78.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:29 AM', '', '1191232655', 'Indiana Burgers - Hebbal', 'DELIVERED', 494.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:32 AM', '', '1074815919', 'Cupcake Bliss - Whitefield', 'DELIVERED', 119.0, 'Ferrero Rocher Cup Cake [Pack of 2]', 1.0, 119.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:35 AM', '', '1347071315', 'Slurpy Shakes - Hebbal', 'DELIVERED', 139.0, 'Mango Cake Shake [250 ml]', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:37 AM', '', '1005937226', 'Indiana Burgers - Whitefield', 'DELIVERED', 109.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:16 AM', '', '24979564016', 'Indiana Burgers - Hebbal', 'DELIVERED', 72.0, 'Veg Burger', 1.0, 72.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:24 AM', '', '24980056276', 'Slurpy Shakes - BTM', 'CANCELLED', 288.0, 'Strawberry Cake Shake (250 ml)', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:24 AM', '', '24980056276', 'Slurpy Shakes - BTM', 'CANCELLED', 288.0, 'Red Velvet Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:27 AM', '', '1581121291', 'Indiana Burgers - Hebbal', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:39 AM', '', '24980940776', 'Slurpy Shakes - Hebbal', 'DELIVERED', 149.0, 'Oreo Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:39 AM', '', '24980971957', 'Warm Oven - Panathur', 'CANCELLED', 479.0, 'Eggless Butterscotch Cake (500 gm)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:46 AM', '', '1326173428', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:47 AM', '', '1100839044', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 357.0, 'Chicken Whopper', 2.0, 278.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:47 AM', '', '1100839044', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 357.0, 'Fries  Meal', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:47 AM', '', '24981462742', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 271.0, 'Fries Combo (French Fries + Coke 250 ml)', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:47 AM', '', '24981462742', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 271.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:47 AM', '', '24981462742', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 271.0, 'Extra Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:51 AM', '', '1280651125', 'Indiana Burgers - Whitefield', 'DELIVERED', 218.0, 'Chicken Burger', 2.0, 218.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:53 AM', '', '24981816810', 'Indiana Burgers - BTM', 'DELIVERED', 188.0, 'Lamb Whopper Burger', 1.0, 167.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:53 AM', '', '24981816810', 'Indiana Burgers - BTM', 'DELIVERED', 188.0, 'Extra Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:53 AM', '', '24981821838', 'Warm Oven - Kammanahalli', 'DELIVERED', 350.0, 'Assorted Cupcakes (Box of 6)', 1.0, 350.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:55 AM', '', '24981914370', 'Warm Oven - Whitefield', 'DELIVERED', 479.0, 'Eggless Black forest Cake ', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '8:58 AM', '', '24982098487', 'Warm Oven - Koramangala', 'DELIVERED', 429.0, 'Butterscotch Cake (500 gms)', 1.0, 429.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:00 AM', '', '24982218217', 'Indiana Burgers - Whitefield', 'DELIVERED', 98.0, 'Chicken Burger', 2.0, 98.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:05 AM', '', '24982511332', 'Indiana Burgers - Hebbal', 'DELIVERED', 72.0, 'Veg Burger', 1.0, 72.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:07 AM', '', '1040879758', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 79.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:11 AM', '', '1606384243', 'Indiana Burgers - Koramangala', 'DELIVERED', 267.0, 'French Fries', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:11 AM', '', '1606384243', 'Indiana Burgers - Koramangala', 'DELIVERED', 267.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:11 AM', '', '1606384243', 'Indiana Burgers - Koramangala', 'DELIVERED', 267.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:12 AM', '', '24982956839', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:15 AM', '', '1075624504', 'Warm Oven - Koramangala', 'DELIVERED', 129.0, 'Death by Chocolate Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:17 AM', '', '24983228927', 'Indiana Burgers - Domlur', 'DELIVERED', 374.0, 'Lamb Burger', 1.0, 125.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:17 AM', '', '24983228927', 'Indiana Burgers - Domlur', 'DELIVERED', 374.0, 'Extra Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:17 AM', '', '24983228927', 'Indiana Burgers - Domlur', 'DELIVERED', 374.0, 'Mayonnaise   ', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:17 AM', '', '24983228927', 'Indiana Burgers - Domlur', 'DELIVERED', 374.0, 'Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:17 AM', '', '24983228927', 'Indiana Burgers - Domlur', 'DELIVERED', 374.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:17 AM', '', '24983228927', 'Indiana Burgers - Domlur', 'DELIVERED', 374.0, 'Extra Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:24 AM', '', '1194009900', 'Indiana Burgers - BTM', 'DELIVERED', 257.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:24 AM', '', '1194009900', 'Indiana Burgers - BTM', 'DELIVERED', 257.0, 'French Fries', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:24 AM', '', '1194009900', 'Indiana Burgers - BTM', 'DELIVERED', 257.0, 'Butterscotch Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:25 AM', '', '24983729835', 'Warm Oven - Panathur', 'CANCELLED', 609.0, 'Eggless Death by Chocolate Cake (500 gm)', 1.0, 609.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:27 AM', '', '1631433756', 'Slurpy Shakes - Hebbal', 'DELIVERED', 149.0, 'Kit Kat Shake [250 ml]', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:30 AM', '', '1473505157', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 79.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:34 AM', '', '1047018808', 'Warm Oven - Kammanahalli', 'DELIVERED', 229.0, 'Red Velvet Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:34 AM', '', '1047018808', 'Warm Oven - Kammanahalli', 'DELIVERED', 229.0, 'Chocolate Slice of Heaven [Box of 2]', 1.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:34 AM', '', '1047018808', 'Warm Oven - Kammanahalli', 'DELIVERED', 229.0, 'Red Velvet Slice of Heaven [Box of 2]', 1.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:35 AM', '', '1525167508', 'Warm Oven - Sarjapur', 'DELIVERED', 609.0, 'Eggless Death by Chocolate Cake [500 gram]', 1.0, 609.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:35 AM', '', '24984334775', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 236.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:35 AM', '', '24984334775', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 236.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:35 AM', '', '24984334775', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 236.0, 'Extra Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:38 AM', '', '24984525323', 'Indiana Burgers - Domlur', 'DELIVERED', 104.0, 'Lamb Burger', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:39 AM', '', '24984598891', 'Indiana Burgers - Whitefield', 'DELIVERED', 453.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:39 AM', '', '24984598891', 'Indiana Burgers - Whitefield', 'DELIVERED', 453.0, 'Fries Combo', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:39 AM', '', '24984598891', 'Indiana Burgers - Whitefield', 'DELIVERED', 453.0, 'Extra Cheese', 3.0, 63.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:39 AM', '', '24984598891', 'Indiana Burgers - Whitefield', 'DELIVERED', 453.0, 'Chicken Burger', 2.0, 228.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:41 AM', '', '1475007768', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 160.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:41 AM', '', '1475007768', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 160.0, 'Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:43 AM', '', '1642373588', 'Slurpy Shakes - Kammanahalli', 'DELIVERED', 129.0, 'Kit Kat Shake [250 ml]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:47 AM', '', '24985073819', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Veg Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:48 AM', '', '24985132289', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 258.0, 'Fries Combo (French Fries + Coke 250 ml)', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:48 AM', '', '24985132289', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 258.0, 'Veg Whopper Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:48 AM', '', '24985132289', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 258.0, 'Extra Mayonnaise (Egg) (50 gms)', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:51 AM', '', '24985261292', 'Warm Oven - Whitefield', 'DELIVERED', 608.0, 'Butterscotch Cake in Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:51 AM', '', '24985261292', 'Warm Oven - Whitefield', 'DELIVERED', 608.0, 'Punchy Pineapple Cake in Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:51 AM', '', '24985261292', 'Warm Oven - Whitefield', 'DELIVERED', 608.0, 'Assorted Cupcakes ', 1.0, 350.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:51 AM', '', '24985292525', 'Warm Oven - Whitefield', 'CANCELLED', 499.0, 'Eggless Chocolate Truffle Cake ', 1.0, 499.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:53 AM', '', '24985422609', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Veg Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:55 AM', '', '24985544555', 'Indiana Burgers - Whitefield', 'DELIVERED', 334.0, 'Lamb Whopper Burger', 2.0, 334.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:01 AM', '', '1241429232', 'Warm Oven - Kammanahalli', 'DELIVERED', 129.0, 'Death by Chocolate Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:04 AM', '', '24986074865', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:05 AM', '', '1451751283', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 139.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:09 AM', '', '24986377429', 'Warm Oven - BTM', 'DELIVERED', 479.0, 'Creamy Chocolate Pastries (Box of 6)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:12 AM', '', '24986567021', 'Cupcake Bliss - Kammanahalli', 'DELIVERED', 218.0, 'Ferrero Rocher Cupcake (Pack of 2)', 1.0, 119.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:12 AM', '', '24986567021', 'Cupcake Bliss - Kammanahalli', 'DELIVERED', 218.0, 'Pineapple Cupcake (Pack of 2)', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:14 AM', '', '1087582048', 'Warm Oven - Hebbal', 'DELIVERED', 129.0, 'Red Velvet Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:18 AM', '', '24986881648', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:18 AM', '', '24986907866', 'Warm Oven - Kammanahalli', 'DELIVERED', 599.0, 'Red Velvet Cake (500 gms)', 1.0, 599.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:23 AM', '', '24987207415', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Veg Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:26 AM', '', '1008252285', 'Warm Oven - BTM', 'DELIVERED', 449.0, 'Chocolate Truffle Cake [500 gram]', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:27 AM', '', '24987461536', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:28 AM', '', '24987534163', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Veg Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:31 AM', '', '1108784963', 'Warm Oven - Whitefield', 'DELIVERED', 499.0, 'Eggless Chocolate Truffle Cake [500 gram]', 1.0, 499.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:32 AM', '', '1339269687', 'Warm Oven - Hebbal', 'DELIVERED', 649.0, 'Eggless Red Velvet Cake [500 gram]', 1.0, 649.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:33 AM', '', '1305614964', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 AM', '', '24987856753', 'Indiana Burgers - Domlur', 'DELIVERED', 104.0, 'Lamb Burger', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 AM', '', '1552368951', 'Indiana Burgers - Malleshwaram', 'CANCELLED', 179.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 AM', '', '1552368951', 'Indiana Burgers - Malleshwaram', 'CANCELLED', 179.0, 'Egg Mayonnaise [50 grams]', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:36 AM', '', '24987977734', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:43 AM', '', '1633144956', 'Indiana Burgers - Koramangala', 'DELIVERED', 134.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:43 AM', '', '1633144956', 'Indiana Burgers - Koramangala', 'DELIVERED', 134.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:44 AM', '', '1558081554', 'Warm Oven - BTM', 'DELIVERED', 140.0, 'Choco Lava [Box of 2]', 1.0, 140.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:44 AM', '', '24988475696', 'Warm Oven - Sarjapur', 'DELIVERED', 258.0, 'Red Velvet In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:44 AM', '', '24988475696', 'Warm Oven - Sarjapur', 'DELIVERED', 258.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:45 AM', '', '24988530140', 'Warm Oven - Hebbal', 'DELIVERED', 1128.0, 'Chocolate Heart Cake (500 gms)', 1.0, 529.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:45 AM', '', '24988530140', 'Warm Oven - Hebbal', 'DELIVERED', 1128.0, 'Red Velvet Cake (500 gm)', 1.0, 599.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:46 AM', '', '24988594672', 'Warm Oven - Domlur', 'DELIVERED', 649.0, 'Eggless Red Velvet Cake (500 gm)', 1.0, 649.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:46 AM', '', '24988615843', 'Slurpy Shakes - Malleshwaram', 'DELIVERED', 288.0, 'Ferrero Rocher Shake (250 ml)', 1.0, 159.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:46 AM', '', '24988615843', 'Slurpy Shakes - Malleshwaram', 'DELIVERED', 288.0, 'Kit Kat Shake (250 ml)', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:53 AM', '', '1343499074', 'Indiana Burgers - Whitefield', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:55 AM', '', '1177413436', 'Indiana Burgers - Domlur', 'DELIVERED', 139.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:55 AM', '', '1392701225', 'Warm Oven - Kaggdaspura', 'DELIVERED', 378.0, 'Death by Chocolate Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:55 AM', '', '1392701225', 'Warm Oven - Kaggdaspura', 'DELIVERED', 378.0, 'Red Velvet Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:55 AM', '', '1392701225', 'Warm Oven - Kaggdaspura', 'DELIVERED', 378.0, 'Red Velvet Shots [Box of 5]', 1.0, 120.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:57 AM', '', '1555378415', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 178.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:57 AM', '', '1555378415', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 178.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:01 AM', '', '1677431466', 'Warm Oven - Panathur', 'DELIVERED', 630.0, 'Assorted Cupcake [Box of 6]', 1.0, 350.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:01 AM', '', '1677431466', 'Warm Oven - Panathur', 'DELIVERED', 630.0, 'Red Velvet Cupcake [Box of 2]', 1.0, 160.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:01 AM', '', '1677431466', 'Warm Oven - Panathur', 'DELIVERED', 630.0, 'Red Velvet Shots [Box of 5]', 1.0, 120.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:04 AM', '', '24989684892', 'Indiana Burgers - Domlur', 'DELIVERED', 167.0, 'Lamb Burger', 1.0, 125.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:04 AM', '', '24989684892', 'Indiana Burgers - Domlur', 'DELIVERED', 167.0, 'Extra Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:04 AM', '', '24989684892', 'Indiana Burgers - Domlur', 'DELIVERED', 167.0, 'Extra Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:05 AM', '', '24989712193', 'Warm Oven - Kammanahalli', 'DELIVERED', 479.0, 'Eggless Black Forest Cake (500 gms)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:07 AM', '', '1425187196', 'Indiana Burgers - Domlur', 'DELIVERED', 178.0, 'Fries Meal', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:07 AM', '', '1425187196', 'Indiana Burgers - Domlur', 'DELIVERED', 178.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:11 AM', '', '24990103350', 'Indiana Burgers - Whitefield', 'DELIVERED', 98.0, 'Chicken Burger', 2.0, 98.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:14 AM', '', '1190167773', 'Indiana Burgers - Sarjapur', 'DELIVERED', 178.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:14 AM', '', '1190167773', 'Indiana Burgers - Sarjapur', 'DELIVERED', 178.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:14 AM', '', '24990279222', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:18 AM', '', '24990529006', 'Indiana Burgers - BTM', 'DELIVERED', 146.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:23 AM', '', '24990826340', 'Warm Oven - Sarjapur', 'DELIVERED', 599.0, 'Red Velvet Cake (500 gm)', 1.0, 599.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:30 AM', '', '1294926592', 'Warm Oven - Koramangala', 'DELIVERED', 149.0, 'Chocolate Truffle Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:32 AM', '', '24991366596', 'Warm Oven - Whitefield', 'DELIVERED', 449.0, 'Chocolate Truffle Pastries ', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:35 AM', '', '1093824651', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 203.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:35 AM', '', '1093824651', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 203.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:35 AM', '', '1093824651', 'Indiana Burgers - Kaggdaspura', 'DELIVERED', 203.0, 'Fries Meal', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:39 AM', '', '1240835555', 'Indiana Burgers - Hebbal', 'DELIVERED', 233.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:39 AM', '', '1240835555', 'Indiana Burgers - Hebbal', 'DELIVERED', 233.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:39 AM', '', '1240835555', 'Indiana Burgers - Hebbal', 'DELIVERED', 233.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:41 AM', '', '24991898864', 'Warm Oven - Domlur', 'DELIVERED', 649.0, 'Eggless Red Velvet Cake (500 gm)', 1.0, 649.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:42 AM', '', '24991940490', 'Slurpy Shakes - Sarjapur', 'DELIVERED', 298.0, 'Red Velvet Shake (250 ml)', 2.0, 298.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:45 AM', '', '24992145329', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 375.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:45 AM', '', '24992145329', 'Indiana Burgers - Malleshwaram', 'DELIVERED', 375.0, 'Chicken Whopper Burger', 2.0, 292.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:49 AM', '', '1406127348', 'Warm Oven - Panathur', 'DELIVERED', 129.0, 'Red Velvet Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:49 AM', '', '24992351383', 'Indiana Burgers - Sarjapur', 'DELIVERED', 98.0, 'Veg Burger', 2.0, 98.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:50 AM', '', '1671220177', 'Warm Oven - Whitefield', 'DELIVERED', 429.0, 'Black Forest Cake [500 gram]', 1.0, 429.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:51 AM', '', '24992466113', 'Warm Oven - Whitefield', 'DELIVERED', 599.0, 'Red Velvet Cake ', 1.0, 599.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:53 AM', '', '1001080070', 'Warm Oven - HSR', 'DELIVERED', 258.0, 'Red Velvet Cake [1 Jar]', 2.0, 258.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:55 AM', '', '1420659597', 'Indiana Burgers - HSR', 'DELIVERED', 316.0, 'Veg Burger', 2.0, 158.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:55 AM', '', '1420659597', 'Indiana Burgers - HSR', 'DELIVERED', 316.0, 'French Fries', 2.0, 158.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:57 AM', '', '24992836818', 'Indiana Burgers - Hebbal', 'DELIVERED', 72.0, 'Veg Burger', 1.0, 72.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:59 AM', '', '1003422090', 'Indiana Burgers - Domlur', 'DELIVERED', 218.0, 'Chicken Burger', 2.0, 218.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:02 PM', '', '24993171193', 'Indiana Burgers - Koramangala', 'DELIVERED', 114.0, 'Chicken Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '24993185539', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 1220.0, 'Chicken Burger', 2.0, 228.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '24993185539', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 1220.0, 'Extra Cheese', 5.0, 105.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '24993185539', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 1220.0, 'Extra Mayonnaise (Egg) (50 gms)', 6.0, 240.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '24993185539', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 1220.0, 'Lamb Whopper Burger', 3.0, 501.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '24993185539', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 1220.0, 'Extra Egg', 3.0, 63.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '24993185539', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 1220.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '1634244210', 'Indiana Burgers - Domlur', 'DELIVERED', 208.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:03 PM', '', '1634244210', 'Indiana Burgers - Domlur', 'DELIVERED', 208.0, 'Fries Meal', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:07 PM', '', '24993427817', 'Warm Oven - Sarjapur', 'DELIVERED', 129.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:14 PM', '', '24993858202', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:14 PM', '', '1288119464', 'Warm Oven - Hebbal', 'DELIVERED', 129.0, 'Death by Chocolate Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:16 PM', '', '24993960980', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:18 PM', '', '24994102827', 'Indiana Burgers - Domlur', 'DELIVERED', 458.0, 'Chicken Whopper Burger', 2.0, 292.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:18 PM', '', '24994102827', 'Indiana Burgers - Domlur', 'DELIVERED', 458.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:18 PM', '', '24994102827', 'Indiana Burgers - Domlur', 'DELIVERED', 458.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:21 PM', '', '24994302293', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:27 PM', '', '1448080843', 'Warm Oven - HSR', 'DELIVERED', 449.0, 'Chocolate Truffle Cake [500 gram]', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:32 PM', '', '1353346015', 'Indiana Burgers - Whitefield', 'DELIVERED', 139.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:33 PM', '', '24994998807', 'Indiana Burgers - Hebbal', 'DELIVERED', 125.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:33 PM', '', '24994998807', 'Indiana Burgers - Hebbal', 'DELIVERED', 125.0, 'Extra Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:33 PM', '', '24994998807', 'Indiana Burgers - Hebbal', 'DELIVERED', 125.0, 'Extra Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:35 PM', '', '1117188687', 'Warm Oven - Sarjapur', 'DELIVERED', 350.0, 'Assorted Cupcake [Box of 6]', 1.0, 350.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:36 PM', '', '24995162623', 'Indiana Burgers - Whitefield', 'DELIVERED', 495.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:36 PM', '', '24995162623', 'Indiana Burgers - Whitefield', 'DELIVERED', 495.0, 'Extra Mayonnaise (Veg) (50 gms)', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:36 PM', '', '24995162623', 'Indiana Burgers - Whitefield', 'DELIVERED', 495.0, 'Chocolate Milkshake', 3.0, 207.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:36 PM', '', '24995162623', 'Indiana Burgers - Whitefield', 'DELIVERED', 495.0, 'Lamb Burger', 1.0, 125.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:36 PM', '', '24995162623', 'Indiana Burgers - Whitefield', 'DELIVERED', 495.0, 'Extra Mayonnaise (Egg) (50 gms)', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:37 PM', '', '1536917931', 'Cupcake Bliss - Kammanahalli', 'DELIVERED', 168.0, 'Chocolate Cupcake', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:37 PM', '', '1536917931', 'Cupcake Bliss - Kammanahalli', 'DELIVERED', 168.0, 'Pack of 2', 2.0, 168.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:37 PM', '', '1536917931', 'Cupcake Bliss - Kammanahalli', 'DELIVERED', 168.0, 'Red Velvet Cupcake', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:40 PM', '', '24995413219', 'Indiana Burgers - HSR', 'DELIVERED', 218.0, 'Fries Combo(French Fries + Coke 250 ml)', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:40 PM', '', '24995413219', 'Indiana Burgers - HSR', 'DELIVERED', 218.0, 'Chicken Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:42 PM', '', '24995531846', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:49 PM', '', '24995957109', 'Warm Oven - Sarjapur', 'DELIVERED', 958.0, 'Eggless Black forest Cake (500 gm)', 2.0, 958.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:49 PM', '', '1363052700', 'Indiana Burgers - Hebbal', 'DELIVERED', 173.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:49 PM', '', '1363052700', 'Indiana Burgers - Hebbal', 'DELIVERED', 173.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:49 PM', '', '1363052700', 'Indiana Burgers - Hebbal', 'DELIVERED', 173.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:53 PM', '', '1024856991', 'Warm Oven - Hebbal', 'DELIVERED', 449.0, 'Chocolate Truffle Cake [500 gram]', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:53 PM', '', '24996223701', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:53 PM', '', '24996233023', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:54 PM', '', '1563490310', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 130.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:54 PM', '', '1563490310', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 130.0, 'Cheese', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '12:54 PM', '', '24996291786', 'Indiana Burgers - Whitefield', 'DELIVERED', 99.0, 'Lamb Burger', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:00 PM', '', '1491769785', 'Slurpy Shakes - Whitefield', 'DELIVERED', 298.0, 'Oreo Shake [250 ml]', 2.0, 298.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:01 PM', '', '24996670785', 'Cupcake Bliss - Hebbal', 'DELIVERED', 436.0, 'Oreo Cupcake (Pack of 2)', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:01 PM', '', '24996670785', 'Cupcake Bliss - Hebbal', 'DELIVERED', 436.0, 'Mango Cupcake (Pack of 2)', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:01 PM', '', '24996670785', 'Cupcake Bliss - Hebbal', 'DELIVERED', 436.0, 'Red velvet Cupcake (Pack of 2)', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:01 PM', '', '24996670785', 'Cupcake Bliss - Hebbal', 'DELIVERED', 436.0, 'Ferrero Rocher Cupcake (Pack of 2)', 1.0, 119.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:01 PM', '', '24996685260', 'Slurpy Shakes - Hebbal', 'DELIVERED', 298.0, 'Red Velvet Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:01 PM', '', '24996685260', 'Slurpy Shakes - Hebbal', 'DELIVERED', 298.0, 'Brownie Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:04 PM', '', '24996872281', 'Warm Oven - BTM', 'DELIVERED', 649.0, 'Eggless Red Velvet Cake (500 gm)', 1.0, 649.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:05 PM', '', '24996925944', 'Warm Oven - Sarjapur', 'DELIVERED', 258.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:05 PM', '', '24996925944', 'Warm Oven - Sarjapur', 'DELIVERED', 258.0, 'Red Velvet In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:12 PM', '', '24997364741', 'Indiana Burgers - Panathur', 'DELIVERED', 114.0, 'Veg Whopper Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:14 PM', '', '1204718469', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 79.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:17 PM', '', '1543582693', 'Indiana Burgers - Koramangala', 'DELIVERED', 159.0, 'Lamb Whopper', 1.0, 159.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:20 PM', '', '24997807908', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:21 PM', '', '1318830786', 'Indiana Burgers - Hebbal', 'DELIVERED', 109.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:25 PM', '', '1369085321', 'Indiana Burgers - HSR', 'DELIVERED', 228.0, 'Fries Meal', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:25 PM', '', '1369085321', 'Indiana Burgers - HSR', 'DELIVERED', 228.0, 'Cheese', 2.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:25 PM', '', '1369085321', 'Indiana Burgers - HSR', 'DELIVERED', 228.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:25 PM', '', '1341436305', 'Warm Oven - Kammanahalli', 'DELIVERED', 1088.0, 'Chocolate Heart Cake [500 gram]', 1.0, 529.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:25 PM', '', '1341436305', 'Warm Oven - Kammanahalli', 'DELIVERED', 1088.0, 'Death by Chocolate Cake [500 gram]', 1.0, 559.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:26 PM', '', '1663986820', 'Indiana Burgers - Whitefield', 'DELIVERED', 446.0, 'Lamb Whopper', 2.0, 318.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:26 PM', '', '1663986820', 'Indiana Burgers - Whitefield', 'DELIVERED', 446.0, 'Cheese', 2.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:26 PM', '', '1663986820', 'Indiana Burgers - Whitefield', 'DELIVERED', 446.0, 'Egg Mayonnaise [50 grams]', 2.0, 78.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:27 PM', '', '24998246433', 'Indiana Burgers - Sarjapur', 'DELIVERED', 215.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:27 PM', '', '24998246433', 'Indiana Burgers - Sarjapur', 'DELIVERED', 215.0, 'Butter Scotch Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:27 PM', '', '1566283828', 'Indiana Burgers - BTM', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:28 PM', '', '24998332262', 'Cupcake Bliss - BTM', 'DELIVERED', 558.0, 'Ferrero Rocher Cupcake (Pack of 6)', 1.0, 289.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:28 PM', '', '24998332262', 'Cupcake Bliss - BTM', 'DELIVERED', 558.0, 'Red velvet Cupcake (Pack of 6)', 1.0, 269.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:30 PM', '', '24998457445', 'Warm Oven - Kaggdaspura', 'DELIVERED', 350.0, 'Assorted Cupcakes (Box of 6)', 1.0, 350.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:31 PM', '', '1144814489', 'Slurpy Shakes - Hebbal', 'DELIVERED', 189.0, 'Ferrero Rocher Shake [250 ml]', 1.0, 189.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:38 PM', '', '24998924776', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:39 PM', '', '1163256428', 'Indiana Burgers - Panathur', 'DELIVERED', 208.0, 'Fries Meal', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:39 PM', '', '1163256428', 'Indiana Burgers - Panathur', 'DELIVERED', 208.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:40 PM', '', '24999004322', 'Cupcake Bliss - Whitefield', 'DELIVERED', 99.0, 'Mango Cupcake (Pack of 2)', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:40 PM', '', '24999031133', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:43 PM', '', '24999227316', 'Warm Oven - Kammanahalli', 'DELIVERED', 429.0, 'Black Forest Cake (500 gms)', 1.0, 429.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:44 PM', '', '24999273717', 'Indiana Burgers - Panathur', 'DELIVERED', 202.0, 'Mayonnaise   ', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:44 PM', '', '24999273717', 'Indiana Burgers - Panathur', 'DELIVERED', 202.0, 'Fries Combo', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:44 PM', '', '24999273717', 'Indiana Burgers - Panathur', 'DELIVERED', 202.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:44 PM', '', '24999284061', 'Indiana Burgers - Sarjapur', 'DELIVERED', 123.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:44 PM', '', '24999284061', 'Indiana Burgers - Sarjapur', 'DELIVERED', 123.0, 'Veg Mayonnaise', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:52 PM', '', '24999767825', 'Bombay Kulfi - Whitefield', 'DELIVERED', 540.0, 'Kesar Badam Kulfi', 1.0, 120.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:52 PM', '', '24999767825', 'Bombay Kulfi - Whitefield', 'DELIVERED', 540.0, 'Mango Kulfi  ', 1.0, 190.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:52 PM', '', '24999767825', 'Bombay Kulfi - Whitefield', 'DELIVERED', 540.0, 'Custard Apple Kulfi  ', 1.0, 230.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:54 PM', '', '24999883501', 'Indiana Burgers - Domlur', 'DELIVERED', 208.0, 'Lamb Burger', 1.0, 125.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:54 PM', '', '24999883501', 'Indiana Burgers - Domlur', 'DELIVERED', 208.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:54 PM', '', '24999891774', 'Warm Oven - Hebbal', 'DELIVERED', 449.0, 'Chocolate Truffle Pastries (Box of 6)', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:55 PM', '', '24999903170', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:56 PM', '', '24999963949', 'Warm Oven - Malleshwaram', 'DELIVERED', 129.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:56 PM', '', '25000009401', 'Warm Oven - Kammanahalli', 'DELIVERED', 479.0, 'Eggless Black Forest Cake (500 gms)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:57 PM', '', '25000060966', 'Warm Oven - Whitefield', 'DELIVERED', 599.0, 'Red Velvet Cake ', 1.0, 599.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:59 PM', '', '25000177385', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '1:59 PM', '', '25000186621', 'Warm Oven - Whitefield', 'DELIVERED', 649.0, 'Eggless Red Velvet Cake ', 1.0, 649.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:02 PM', '', '25000347725', 'Warm Oven - Sarjapur', 'DELIVERED', 499.0, 'Eggless Chocolate Truffle Cake (500 gm)', 1.0, 499.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:04 PM', '', '25000470622', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:05 PM', '', '25000503632', 'Warm Oven - Kaggdaspura', 'DELIVERED', 350.0, 'Assorted Cupcakes (Box of 6)', 1.0, 350.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:05 PM', '', '1311855040', 'Indiana Burgers - Domlur', 'DELIVERED', 208.0, 'Fries Meal', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:05 PM', '', '1311855040', 'Indiana Burgers - Domlur', 'DELIVERED', 208.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:07 PM', '', '25000632465', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:07 PM', '', '1498655457', 'Slurpy Shakes - Kammanahalli', 'DELIVERED', 129.0, 'Brownie Shake [250 ml]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:07 PM', '', '25000653109', 'Indiana Burgers - HSR', 'DELIVERED', 104.0, 'Lamb Burger                                           ', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:08 PM', '', '25000702584', 'Indiana Burgers - Panathur', 'DELIVERED', 114.0, 'Veg Whopper Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:08 PM', '', '25000728387', 'Warm Oven - Kaggdaspura', 'DELIVERED', 129.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:08 PM', '', '25000737642', 'Indiana Burgers - Panathur', 'DELIVERED', 297.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:08 PM', '', '25000737642', 'Indiana Burgers - Panathur', 'DELIVERED', 297.0, 'Lamb Whopper Burger', 1.0, 167.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:08 PM', '', '25000737642', 'Indiana Burgers - Panathur', 'DELIVERED', 297.0, 'Extra Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:08 PM', '', '25000737642', 'Indiana Burgers - Panathur', 'DELIVERED', 297.0, 'Extra Mayonnaise (Egg) (50 gms)', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:09 PM', '', '25000764488', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:09 PM', '', '25000790280', 'Warm Oven - Hebbal', 'DELIVERED', 479.0, 'Creamy Chocolate Pastries (Box of 6)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:10 PM', '', '25000814034', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:11 PM', '', '25000892390', 'Indiana Burgers - HSR', 'CANCELLED', 208.0, 'Lamb Burger                                           ', 2.0, 208.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:16 PM', '', '1549780029', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 188.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:16 PM', '', '1549780029', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 188.0, 'Fries  Meal', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:16 PM', '', '25001215887', 'Indiana Burgers - Whitefield', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:19 PM', '', '25001343654', 'Indiana Burgers - Sarjapur', 'DELIVERED', 204.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:19 PM', '', '25001343654', 'Indiana Burgers - Sarjapur', 'DELIVERED', 204.0, 'Cheese', 2.0, 42.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:19 PM', '', '25001343654', 'Indiana Burgers - Sarjapur', 'DELIVERED', 204.0, 'Fries Combo ', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:20 PM', '', '25001416701', 'Indiana Burgers - Hebbal', 'DELIVERED', 308.0, 'Butter Scotch Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:20 PM', '', '25001416701', 'Indiana Burgers - Hebbal', 'DELIVERED', 308.0, 'Chicken Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:20 PM', '', '25001416701', 'Indiana Burgers - Hebbal', 'DELIVERED', 308.0, 'Lamb Burger', 1.0, 125.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:20 PM', '', '25001434240', 'Cupcake Bliss - HSR', 'DELIVERED', 287.0, 'Vanilla Cupcake (Pack of 2)', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:20 PM', '', '25001434240', 'Cupcake Bliss - HSR', 'DELIVERED', 287.0, 'Chocolate Cupcake (Pack of 2)', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:20 PM', '', '25001434240', 'Cupcake Bliss - HSR', 'DELIVERED', 287.0, 'Red velvet Cupcake (Pack of 2)', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:21 PM', '', '1409183389', 'Indiana Burgers - Hebbal', 'DELIVERED', 134.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:21 PM', '', '1409183389', 'Indiana Burgers - Hebbal', 'DELIVERED', 134.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:24 PM', '', '1227584877', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 239.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:24 PM', '', '1227584877', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 239.0, 'Egg', 1.0, 21.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:24 PM', '', '1227584877', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 239.0, 'Egg Mayonnaise [50 grams]', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:24 PM', '', '1227584877', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 239.0, 'French Fries', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:27 PM', '', '25001827878', 'Warm Oven - Sarjapur', 'DELIVERED', 140.0, 'Choco Lava', 1.0, 140.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:27 PM', '', '25001827878', 'Warm Oven - Sarjapur', 'DELIVERED', 140.0, 'Pack of 2', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:31 PM', '', '1677455650', 'Indiana Burgers - Hebbal', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:34 PM', '', '1016367788', 'Warm Oven - Malleshwaram', 'DELIVERED', 449.0, 'Chocolate Truffle Cake [500 gram]', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:35 PM', '', '1035247129', 'Warm Oven - Kaggdaspura', 'DELIVERED', 100.0, 'Red Velvet Slice of Heaven [Box of 2]', 2.0, 100.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:36 PM', '', '1380611088', 'Indiana Burgers - BTM', 'DELIVERED', 203.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:36 PM', '', '1380611088', 'Indiana Burgers - BTM', 'DELIVERED', 203.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:36 PM', '', '1380611088', 'Indiana Burgers - BTM', 'DELIVERED', 203.0, 'Egg Mayonnaise [50 grams]', 1.0, 39.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:38 PM', '', '25002514562', 'Warm Oven - BTM', 'DELIVERED', 129.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:39 PM', '', '25002584249', 'Slurpy Shakes - Whitefield', 'DELIVERED', 149.0, 'Red Velvet Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:41 PM', '', '1294773893', 'Warm Oven - Domlur', 'DELIVERED', 129.0, 'Death by Chocolate Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:41 PM', '', '25002703210', 'Slurpy Shakes - Malleshwaram', 'DELIVERED', 129.0, 'Kit Kat Shake (250 ml)', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:46 PM', '', '25003004550', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 187.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:46 PM', '', '25003004550', 'Indiana Burgers - Kammanahalli', 'DELIVERED', 187.0, 'Fries Combo (French Fries + Coke 250 ml)', 1.0, 104.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:47 PM', '', '25003047608', 'Indiana Burgers - Sarjapur', 'DELIVERED', 49.0, 'Fries Combo', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:50 PM', '', '25003233829', 'Warm Oven - Domlur', 'DELIVERED', 479.0, 'Creamy Chocolate Pastries (Box of 6)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '2:52 PM', '', '25003356618', 'Warm Oven - Kammanahalli', 'DELIVERED', 699.0, 'Naked Red Velvet Heart Cake', 1.0, 699.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ...
# ['2018-11-11', '9:56 PM', '', '25028767849', 'Slurpy Shakes - BTM', 'DELIVERED', 149.0, 'Brownie Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:56 PM', '', '25028790440', 'Cupcake Bliss - Panathur', 'DELIVERED', 49.0, 'Ferrero Rocher Cupcake Box of 2', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:58 PM', '', '25028890095', 'Slurpy Shakes - Kammanahalli', 'DELIVERED', 302.0, 'Brownie Shake (250 ml)', 1.0, 156.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:58 PM', '', '25028890095', 'Slurpy Shakes - Kammanahalli', 'DELIVERED', 302.0, 'Dutch Truffle Shake (250 ml)', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:58 PM', '', '1369985110', 'Indiana Burgers - Panathur', 'CANCELLED', 104.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '9:58 PM', '', '1369985110', 'Indiana Burgers - Panathur', 'CANCELLED', 104.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:00 PM', '', '25029019402', 'Warm Oven - HSR', 'DELIVERED', 449.0, 'Chocolate Truffle Pastries (Box of 6)', 1.0, 449.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:00 PM', '', '25029059304', 'Slurpy Shakes - Kaggdaspura', 'DELIVERED', 302.0, 'Dutch Truffle Shake (250 ml)', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:00 PM', '', '25029059304', 'Slurpy Shakes - Kaggdaspura', 'DELIVERED', 302.0, 'Brownie Shake (250 ml)', 1.0, 156.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:01 PM', '', '25029114710', 'Cupcake Bliss - Domlur', 'DELIVERED', 109.0, 'Red velvet Cupcake (Pack of 2)', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:02 PM', '', '25029150538', 'Warm Oven - Kammanahalli', 'DELIVERED', 479.0, 'Eggless Black Forest Cake (500 gms)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:02 PM', '', '1686514066', 'Warm Oven - Whitefield', 'DELIVERED', 149.0, 'Brownie Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:04 PM', '', '1671763263', 'Indiana Burgers - Whitefield', 'DELIVERED', 178.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:04 PM', '', '1671763263', 'Indiana Burgers - Whitefield', 'DELIVERED', 178.0, 'Butterscotch Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:05 PM', '', '25029354508', 'Slurpy Shakes - Domlur', 'DELIVERED', 139.0, 'Pineapple Cake Shake (250 ml)', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:07 PM', '', '25029447671', 'Warm Oven - Panathur', 'DELIVERED', 149.0, 'Brownie Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:10 PM', '', '25029648113', 'Slurpy Shakes - BTM', 'DELIVERED', 99.0, 'Red Velvet Shake', 1.0, 99.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:12 PM', '', '25029729902', 'Indiana Burgers - Domlur', 'DELIVERED', 601.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:12 PM', '', '25029729902', 'Indiana Burgers - Domlur', 'DELIVERED', 601.0, 'Lamb Whopper Burger', 1.0, 167.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:12 PM', '', '25029729902', 'Indiana Burgers - Domlur', 'DELIVERED', 601.0, 'Brownie Shake (250ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:12 PM', '', '25029729902', 'Indiana Burgers - Domlur', 'DELIVERED', 601.0, 'Dutch Truffle Shake (250ml)', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:13 PM', '', '25029816817', 'Indiana Burgers - Whitefield', 'DELIVERED', 166.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:13 PM', '', '25029816817', 'Indiana Burgers - Whitefield', 'DELIVERED', 166.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:15 PM', '', '25029940376', 'Warm Oven - Panathur', 'DISPATCHED', 149.0, 'Chocolate Truffle Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:16 PM', '', '25029999542', 'Warm Oven - Hebbal', 'DELIVERED', 129.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:18 PM', '', '1361553691', 'Indiana Burgers - BTM', 'DELIVERED', 257.0, 'Veg Whopper', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:18 PM', '', '1361553691', 'Indiana Burgers - BTM', 'DELIVERED', 257.0, 'French Fries', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:18 PM', '', '1361553691', 'Indiana Burgers - BTM', 'DELIVERED', 257.0, 'Butterscotch Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:19 PM', '', '25030151597', 'Warm Oven - Koramangala', 'DELIVERED', 140.0, 'Choco Lava', 1.0, 140.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:19 PM', '', '25030151597', 'Warm Oven - Koramangala', 'DELIVERED', 140.0, 'Pack of 2', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:20 PM', '', '25030216856', 'Warm Oven - Panathur', 'DISPATCHED', 140.0, 'Choco Lava', 1.0, 140.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:20 PM', '', '25030216856', 'Warm Oven - Panathur', 'DISPATCHED', 140.0, 'Pack of 2', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:21 PM', '', '1598087470', 'Warm Oven - Kammanahalli', 'ACCEPTED', 649.0, 'Eggless Red Velvet Cake [Box of 6 Pieces]', 1.0, 649.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:21 PM', '', '25030301466', 'Cupcake Bliss - Panathur', 'DELIVERED', 49.0, 'Ferrero Rocher Cupcake Box of 2', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:21 PM', '', '1425850524', 'Indiana Burgers - Domlur', 'DELIVERED', 247.0, 'Chocolate Milkshake', 2.0, 138.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:21 PM', '', '1425850524', 'Indiana Burgers - Domlur', 'DELIVERED', 247.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:25 PM', '', '25030530682', 'Warm Oven - Whitefield', 'CANCELLED', 499.0, 'EgglessChocolate Truffle Pastries (Box of 6)', 1.0, 499.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:26 PM', '', '25030602939', 'Indiana Burgers - Panathur', 'DISPATCHED', 49.0, 'Chicken Burger', 1.0, 49.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:29 PM', '', '1491449976', 'Indiana Burgers - BTM', 'DELIVERED', 417.0, 'Chicken Whopper', 3.0, 417.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:29 PM', '', '25030764815', 'Warm Oven - Whitefield', 'DELIVERED', 129.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:33 PM', '', '1569660274', 'Indiana Burgers - Hebbal', 'DELIVERED', 218.0, 'Veg Whopper', 2.0, 218.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 PM', '', '1461225310', 'Indiana Burgers - HSR', 'DISPATCHED', 353.0, 'Lamb Burger', 1.0, 119.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 PM', '', '1461225310', 'Indiana Burgers - HSR', 'DISPATCHED', 353.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 PM', '', '1461225310', 'Indiana Burgers - HSR', 'DISPATCHED', 353.0, 'Egg', 2.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:34 PM', '', '1461225310', 'Indiana Burgers - HSR', 'DISPATCHED', 353.0, 'Lamb Whopper', 1.0, 159.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:35 PM', '', '25031119676', 'Warm Oven - Panathur', 'DISPATCHED', 179.0, 'Death By Chocolate In A Jar', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:35 PM', '', '25031119676', 'Warm Oven - Panathur', 'DISPATCHED', 179.0, 'Chocolate Slice of Heaven', 1.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:35 PM', '', '25031119676', 'Warm Oven - Panathur', 'DISPATCHED', 179.0, '2 Pcs', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:36 PM', '', '25031207098', 'Warm Oven - Whitefield', 'DELIVERED', 429.0, 'Butterscotch Cake ', 1.0, 429.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:37 PM', '', '25031234527', 'Warm Oven - Kaggdaspura', 'DELIVERED', 479.0, 'Eggless Black Forest Cake (500 gms)', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:38 PM', '', '1096901578', 'Warm Oven - Hebbal', 'DELIVERED', 149.0, 'Brownie Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:38 PM', '', '25031313846', 'Cupcake Bliss - Sarjapur', 'DELIVERED', 109.0, 'Red velvet Cupcake (Pack of 2)', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:38 PM', '', '1436208423', 'Warm Oven - Whitefield', 'DELIVERED', 179.0, 'Death by Chocolate Cake [1 Jar]', 1.0, 129.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:38 PM', '', '1436208423', 'Warm Oven - Whitefield', 'DELIVERED', 179.0, 'Red Velvet Slice of Heaven [Box of 2]', 1.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:45 PM', '', '25031717103', 'Indiana Burgers - Domlur', 'DELIVERED', 125.0, 'Lamb Burger', 1.0, 125.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:48 PM', '', '1147298912', 'Indiana Burgers - Koramangala', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:48 PM', '', '1166116243', 'Indiana Burgers - Hebbal', 'DELIVERED', 69.0, 'Butterscotch Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:50 PM', '', '25032043728', 'Warm Oven - Hebbal', 'DELIVERED', 160.0, 'Red Velvet Cupcakes ', 1.0, 160.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:50 PM', '', '25032043728', 'Warm Oven - Hebbal', 'DELIVERED', 160.0, 'Box of 2', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:51 PM', '', '25032103510', 'Warm Oven - Hebbal', 'DELIVERED', 149.0, 'Chocolate Truffle Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:53 PM', '', '25032225205', 'Indiana Burgers - Whitefield', 'DELIVERED', 269.0, 'French Fries  ', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:53 PM', '', '25032225205', 'Indiana Burgers - Whitefield', 'DELIVERED', 269.0, 'Extra Mayonnaise (Egg) (50 gms)', 1.0, 40.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '10:53 PM', '', '25032225205', 'Indiana Burgers - Whitefield', 'DELIVERED', 269.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:02 PM', '', '25032731216', 'Indiana Burgers - Hebbal', 'DELIVERED', 239.0, 'Chicken Burger', 1.0, 114.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:02 PM', '', '25032731216', 'Indiana Burgers - Hebbal', 'DELIVERED', 239.0, 'Extra Cheese', 2.0, 42.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:02 PM', '', '25032731216', 'Indiana Burgers - Hebbal', 'DELIVERED', 239.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:04 PM', '', '25032844329', 'Warm Oven - Whitefield', 'DELIVERED', 479.0, 'Eggless Black forest Cake ', 1.0, 479.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:06 PM', '', '1298401625', 'Slurpy Shakes - Whitefield', 'DELIVERED', 149.0, 'Brownie Shake [250 ml]', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:07 PM', '', '1425151452', 'Indiana Burgers - Hebbal', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:08 PM', '', '25033114824', 'Indiana Burgers - Hebbal', 'DELIVERED', 83.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:14 PM', '', '1311979553', 'Warm Oven - Whitefield', 'DELIVERED', 499.0, 'Eggless Chocolate Truffle Cake [500 gram]', 1.0, 499.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:14 PM', '', '1373446934', 'Slurpy Shakes - Hebbal', 'DELIVERED', 149.0, 'Kit Kat Shake [250 ml]', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:16 PM', '', '25033560746', 'Slurpy Shakes - Hebbal', 'DELIVERED', 149.0, 'Kit Kat Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:18 PM', '', '1115146517', 'Warm Oven - Hebbal', 'CANCELLED', 559.0, 'Death by Chocolate Cake [500 gram]', 1.0, 559.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:21 PM', '', '25033908465', 'Slurpy Shakes - Hebbal', 'DELIVERED', 338.0, 'Kit Kat Shake (250 ml)', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:21 PM', '', '25033908465', 'Slurpy Shakes - Hebbal', 'DELIVERED', 338.0, 'Ferrero Rocher Shake (250 ml)', 1.0, 189.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:22 PM', '', '1253434536', 'Warm Oven - Whitefield', 'DELIVERED', 699.0, 'Naked Red Velvet Heart Cake [500 gram]', 1.0, 699.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:24 PM', '', '25034057683', 'Indiana Burgers - Whitefield', 'DELIVERED', 225.0, 'Fries Combo', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:24 PM', '', '25034057683', 'Indiana Burgers - Whitefield', 'DELIVERED', 225.0, 'Chicken Whopper Burger', 1.0, 146.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:25 PM', '', '1392924331', 'Cupcake Bliss - Whitefield', 'DELIVERED', 119.0, 'Ferrero Rocher Cup Cake [Pack of 2]', 1.0, 119.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:25 PM', '', '1574062487', 'Indiana Burgers - Hebbal', 'DELIVERED', 164.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:25 PM', '', '1574062487', 'Indiana Burgers - Hebbal', 'DELIVERED', 164.0, 'Egg', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:26 PM', '', '25034168556', 'Warm Oven - Whitefield', 'DELIVERED', 149.0, 'Brownie Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:36 PM', '', '25034812822', 'Warm Oven - Sarjapur', 'DELIVERED', 499.0, 'Eggless Chocolate Truffle Cake (500 gm)', 1.0, 499.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:43 PM', '', '1065133305', 'Indiana Burgers - Sarjapur', 'DELIVERED', 208.0, 'Chicken Whopper', 1.0, 139.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:43 PM', '', '1065133305', 'Indiana Burgers - Sarjapur', 'DELIVERED', 208.0, 'Chocolate Milkshake', 1.0, 69.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:43 PM', '', '1026398680', 'Indiana Burgers - Hebbal', 'DELIVERED', 316.0, 'Veg Burger', 4.0, 316.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:49 PM', '', '1471710972', 'Indiana Burgers - Whitefield', 'DELIVERED', 109.0, 'Chicken Burger', 1.0, 109.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:50 PM', '', '1148494873', 'Warm Oven - Hebbal', 'DELIVERED', 359.0, 'Red Velvet Cupcake [Box of 2]', 1.0, 160.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:50 PM', '', '1148494873', 'Warm Oven - Hebbal', 'DELIVERED', 359.0, 'Red Velvet Slice of Heaven [Box of 2]', 1.0, 50.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:50 PM', '', '1148494873', 'Warm Oven - Hebbal', 'DELIVERED', 359.0, 'Chocolate Truffle Sundae', 1.0, 149.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:51 PM', '', '1156287427', 'Indiana Burgers - Hebbal', 'DELIVERED', 184.0, 'Lamb Whopper', 1.0, 159.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:51 PM', '', '1156287427', 'Indiana Burgers - Hebbal', 'DELIVERED', 184.0, 'Cheese', 1.0, 25.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:54 PM', '', '1241576732', 'Indiana Burgers - Hebbal', 'CANCELLED', 297.0, 'Chicken Burger', 2.0, 218.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:54 PM', '', '1241576732', 'Indiana Burgers - Hebbal', 'CANCELLED', 297.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:55 PM', '', '25035941222', 'Indiana Burgers - Whitefield', 'DELIVERED', 162.0, 'Fries Combo', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:55 PM', '', '25035941222', 'Indiana Burgers - Whitefield', 'DELIVERED', 162.0, 'Veg Burger', 1.0, 83.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:56 PM', '', '25035977409', 'Warm Oven - Sarjapur', 'CANCELLED', 559.0, 'Death by Chocolate Cake (500 gm)', 1.0, 559.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:56 PM', '', '25036009596', 'Warm Oven - Whitefield', 'DELIVERED', 140.0, 'Choco Lava', 1.0, 140.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:56 PM', '', '25036009596', 'Warm Oven - Whitefield', 'DELIVERED', 140.0, 'Pack of 2', 1.0, 0.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ['2018-11-11', '11:57 PM', '', '1402729764', 'Indiana Burgers - Sarjapur', 'DELIVERED', 79.0, 'Veg Burger', 1.0, 79.0, 'No', 0.0, 0.0, 0.0, 0.0]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c8f3405e841> in <module>()
#      26
#      27 with open('Swiggy_14th.csv') as csvfile:
# ---> 28     reader = csv.reader(csvfile)
#      29     i = 0
#      30     header = []
#
# NameError: name 'csv' is not defined

# %%
item_count = 0
with conn.cursor() as cur:
    cur.execute('insert into testpy (id, name) values("5", "Joe")')
    conn.commit()
    cur.execute("select * from testpy")
    for row in cur:
        item_count += 1
        print (row)
conn.commit()
# Out:
# ('1', 'Joe')
# ('2', 'Joe')
# ('3', 'Joe')
# ('4', 'Joe')
# ('5', 'Joe')

# %%
            # 19/09/18
    # 5:15 PM
    # datetime.strptime("21/11/06 16:30", "%d/%m/%y %H:%M")
        #date = datetime.strptime('September 14 2018',  '%B %d %Y')
        # ' does not match format '%d/%m/%y %H:%M'
date = datetime.strptime('23-09-2018 22:15',  '%d-%m-%Y %H:%M')
print (date)
# Out:
# 2018-09-23 22:15:00
